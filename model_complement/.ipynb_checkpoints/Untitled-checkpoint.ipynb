# %%
import json
import glob
import os
from collections import Counter
import pandas as pd
from tqdm import tqdm
from itertools import combinations
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['font.serif'] = ['Libertine', 'Times New Roman']
import matplotlib.pyplot as plt
import seaborn as sns

# %%
root_bench = '../../ake-benchmarking/'

# %%
get_dataset = lambda x: os.path.basename(x).split('.')[0]
get_method = lambda x: '.'.join(os.path.basename(x).split('.')[1:-2])
get_ref_path = lambda d: os.path.join(
    os.environ['PATH_AKE_DATASETS'], 'datasets', d, 'references', 'test.{}.stem.json'.format(reference[d]))

# %%
files = glob.glob(root_bench + 'output/*/*.stem.json')
# methods = sorted(set(map(get_method, files)))
# datasets = sorted(set(map(get_dataset, files)))
methods = [
    'FirstPhrases', 'TextRank', 'TfIdf',
    'PositionRank', 'MultipartiteRank', 'EmbedRank',
    'Kea', 'CopyRNN', 'CopyCorrRNN' , 'CopyRNN_News', 'CopyCorrRNN_News'
]
dataset = [
    'PubMed', 'ACM', 'SemEval-2010',
    'Inspec', 'WWW', 'KP20k',
    'DUC-2001', '500N-KPCrowd','NYTime'
    #'WikinewsKeyphrase', 'TermITH-Eval', 'NUS', 'NTCIR1+2', 'KDD', 'JPTime', 'Citeulike-180', 'CSTR', 'KPTimes', '110-PT-BN-KP',
]
files = [f for f in files if get_method(f) in methods and get_dataset(f) in dataset]

# %%
def load_n_flatten_set(fp, n=None):
    # Load ref, select top-n, flatten and turn into set
    if isinstance(n, int):
        n = [n]
    with open(fp) as f:
        ref = json.load(f)
        if n:
            ref = {i: {k: set(va for kp in v[:i] for va in kp) for k, v in ref.items()} for i in n}
        else:
            ref = {k: set(va for kp in v[:i] for va in kp) for k, v in ref.items()}
    return ref

# %%
def display_heatmap(df, order, value='int_per_doc', ax=None, **kwargs):
    ttmp = df.groupby(['method_a', 'method_b'])[value].mean()\
         .unstack().reindex(columns=order).reindex(order).apply(lambda x: round(x, 1))
    ttmp.index.name = ''
    ttmp.columns.name = ''
    fig = sns.heatmap(ttmp, square=True, annot=True, annot_kws={'size': '3'},
                      linewidths=.1, cmap=sns.cubehelix_palette(8, start=3, rot=-.5),
                      **kwargs)
    for label in fig.axes.xaxis.get_majorticklabels():
        label.set_rotation(30)
        label.set_horizontalalignment("right")
    fig.tick_params(labelsize=5)
    return fig

# %%
reference = {
'CSTR': 'author',
'NUS': 'combined',
'PubMed': 'author',
'ACM': 'author',
'ACM-abstract': 'author',
'Citeulike-180': 'reader',
'SemEval-2010': 'combined',
'SemEval-2010-abstract': 'combined',
'Inspec': 'uncontr',
'KDD': 'author',
'WWW': 'author',
'TermITH': 'indexer',
'KP20k': 'author',
'DUC-2001': 'reader',
'110-PT-BN-KP': 'reader',
'500N-KPCrowd': 'reader',
'WikinewsKeyphrase': 'reader',
'NYTime': 'author'}

# %% [markdown]
# ### Compute Intersection between output keywords

# %%
if os.path.exists('cache.csv'):
    df = pd.read_csv('cache.csv')

# %%
data = []

for i, p_a in enumerate(tqdm(files)):
    d = get_dataset(p_a)
    kp_a = load_n_flatten_set(p_a, n=[5, 10])
    # Load ref
    # filter good keyphrases
    ref_a = load_n_flatten_set(get_ref_path(d))
    good_kp_a = {key: value & ref_a[key] for key, value in kp_a[10].items()}
    bad_kp_a = {key: value - ref_a[key] for key, value in kp_a[10].items()}

    for j, p_b in enumerate(files):
        if j <= i:
            continue
        if get_dataset(p_b) != d:
            continue
        # p_b is Same dataset other method
        kp_b = load_n_flatten_set(p_b, n=[5, 10])
        # Load ref
        # filter good keyphrases
        ref_b = load_n_flatten_set(get_ref_path(d))
        good_kp_b = {key: value & ref_b[key] for key, value in kp_b[10].items()}
        bad_kp_b = {key: value - ref_a[key] for key, value in kp_b[10].items()}

        inter10 = sum(len(kp_a[10][k] & kp_b[10][k]) for k in kp_a[10]) / nb_doc
        inter5 = sum(len(kp_a[5][k] & kp_b[5][k]) for k in kp_a[5]) / nb_doc
        
        rappel5 = sum(len(kp_a[5][k] | kp_b[5][k]) & ref[k] for k in kp_a[5]) / nb_doc
        rappel10 = sum(len(kp_a[10][k] | kp_b[10][k]) & ref[k] for k in kp_a[10]) / nb_doc
        
        good_inter = sum(len(good_kp_a[k] & good_kp_b[k]) for k in good_kp_a) / nb_doc
        bad_inter = sum(len(bad_kp_a[k] & bad_kp_b[k]) for k in bad_kp_a) / nb_doc

        nb_doc = len(kp_a[10])
        data.append([d, get_method(p_a), get_method(p_b), nb_doc, inter5, inter10, rappel5, rappel10, good_inter, bad_inter])
        data.append([d, get_method(p_b), get_method(p_a), nb_doc, inter5, inter10, rappel5, rappel10, good_inter, bad_inter])
# Out:
#   0%|          | 0/93 [00:00<?, ?it/s]
# [5, 10]
# {5: {'AP830325-0143': {'oil', 'spill', 'gallon', 'coast guard', 'vessel'}, 'AP880217-0175': {'spokesmen', 'illeg alien', 'unfair shift', 'censu bureau', 'american immigr reform'}, 'AP880318-0051': {'drum', 'southern philippin', 'sun', 'eclips', 'indonesia'}, 'AP880330-0119': {'georgia', 'illeg alien', 'hous seat', 'seat', 'censu'}, 'AP880331-0140': {'spring thunderstorm', 'weather condit', 'april', 'tornado', 'texa'}, 'AP880409-0015': {'gray', 'averag hurrican', 'el nino', 'hurrican', 'atlant hurrican'}, 'AP880419-0131': {'peavi', 'sever home', 'madison', 'tornado', 'dawn today'}, 'AP880510-0178': {'arafat', 'assassin', 'abu jihad', 'plo', 'plo offici'}, 'AP880517-0226': {'airplan', 'dirt road', 'single-engin airplan', 'albuquerqu', 'ramazzini'}, 'AP880520-0264': {'republ', 'ministri statement', 'special warfar', 'militari council', 'slovenia'}, 'AP880601-0040': {'hurrican', 'coastal flood model', 'atlant', 'mph', 'atlant storm season'}, 'AP880613-0161': {'polic', 'guzman', 'morot', 'path', 'peru'}, 'AP880623-0135': {'illeg alien', 'citizen', 'censu bureau', 'censu subcommitte hear', 'censu'}, 'AP880629-0159': {'lenxweil', 'aircraft', 'west german polic', 'air forc spokeswoman', 'pilot'}, 'AP880630-0295': {'graze', 'usda', 'drought', 'hay', 'lyng'}, 'AP880705-0006': {'fire', 'acr', 'firefight', 'lightning-spark fire', 'firework'}, 'AP880705-0018': {'fire', 'acr', 'control monday', 'firefight', 'bluedorn'}, 'AP880705-0109': {'wilder area', 'fire', 'blaze', 'acr', 'firefight'}, 'AP880714-0142': {'extrem drought', 'tennesse valley', 'larg area', 'northern great plain', 'texa'}, 'AP880801-0195': {'fire', 'mark twain', 'arson', 'arsonist', 'smallwood'}, 'AP880811-0299': {'usda expert', 'percent', 'wilson', 'drought', 'bushel'}, 'AP880816-0234': {'ayacucho', 'path member', 'path guerrilla', 'peasant', 'maoist group'}, 'AP880901-0052': {'forest fire develop', 'western state', 'brief look'}, 'AP880902-0062': {'northern japan', 'forest area', 'tokyo', 'misawa', 'pilot'}, 'AP880903-0092': {'work requir', 'best way', 'downey', 'welfar', 'welfar reform'}, 'AP880913-0129': {'crewman', 'jet', 'el cajon', 'hangar', 'crewmat'}, 'AP880913-0204': {'sheet', 'hurrican', 'beat tuesday', 'first major hurrican', 'gilbert'}, 'AP880914-0027': {'categori', 'storm surg', 'wind', 'gilbert', 'zimmer'}, 'AP880914-0079': {'barometr pressur', 'sheet', 'hurrican', 'gilbert', 'record-break furi'}, 'AP880926-0203': {'ghana', 'debt', 'third world', 'foreign debt', 'brazil'}, 'AP880927-0089': {'johnson', 'complet state', 'stanozolol', 'ben', 'drug'}, 'AP880927-0117': {'johnson', 'charest', 'ben', 'calgari', 'canada'}, 'AP880928-0054': {'johnson', 'canadian', 'hero', 'sprinter', 'canada'}, 'AP880928-0146': {'johnson', 'drug scandal', 'shame', 'stanzolol', 'canada'}, 'AP881009-0072': {'johnson', 'jami', 'astaphan', 'steroid', 'olymp'}, 'AP881017-0235': {'napoleon', 'tunnel', 'dig', 'eurotunnel', 'feet'}, 'AP881018-0136': {'bolivar', 'town', 'colombia', 'mph wind', 'joan'}, 'AP881126-0007': {'diabet', 'amylin', 'pancreas', 'insulin', 'hormon'}, 'AP881206-0114': {'plane', 'runway', 'b-1b', 'peck', 'sawyer'}, 'AP881210-0115': {'remscheid', 'accid', 'west germani', 'public support', 'wellershoff'}, 'AP881211-0027': {'de la garza', 'hear', 'garza', 'last summer', 'summer fire'}, 'AP881216-0017': {'wilder area', 'fire', 'co-chairman', 'panel', 'western fire season'}, 'AP881222-0089': {'develop today', 'pan american world airway flight', 'scotland', 'glanc', 'lockerbi'}, 'AP881222-0119': {'arkin', 'equat', 'drought', 'jet stream', 'weather pattern'}, 'AP881222-0126': {'pentagon', 'air forc', 'howard', 'a-10', 'pilot'}, 'AP881227-0185': {'shantytown', 'huaycan', 'guerrilla', 'slum', 'path'}, 'AP890111-0217': {'crash', 'boe', 'cfm56 engin', 'wrong engin', 'engin'}, 'AP890111-0227': {'silver gate', 'winter', 'snow', 'smith', 'cook citi'}, 'AP890117-0132': {'long beach', 'incid', 'citi council today', 'counti prosecutor', 'jackson'}, 'AP890131-0280': {'central sell organ', 'd ...
# [None]
# {None: {'AP830325-0143': {'major environment catastroph', 'alaska', 'crude oil', 'cleanup effort', 'cleanup equip', 'u.s. tanker spill', 'oil spill', '987-foot tanker exxon valdez'}, 'AP880217-0175': {'nation head count', 'illeg alien', 'censu bureau', 'hous apportion', '1990 censu', 'american immigr reform'}, 'AP880318-0051': {'wit', 'tourist', 'wide area', 'partial eclips', 'total eclips', 'solar eclips', 'sun', 'moon'}, 'AP880330-0119': {'nation head count', 'illeg alien', 'hous seat', 'censu bureau', '1990 censu'}, 'AP880331-0140': {'spring thunderstorm', 'properti damag', 'tornado warn', 'tornado watch', 'tornado', 'disast research', 'tornado season', 'texa'}, 'AP880409-0015': {'turbul summer', 'storm', 'hurrican season', 'atlant ocean', 'william gray', 'annual hurrican forecast', 'hurrican expert', 'atlant hurrican'}, 'AP880419-0131': {'thunderstorm', 'destruct', 'madison', 'tornado watch', 'tornado', 'death'}, 'AP880510-0178': {'unit state', 'isra offici', 'plo leader yasser arafat', 'american target', 'palestinian guerrilla', 'accus', 'khalil wazir', 'isra squad', 'plo offici', 'polit assassin', 'possibl plo attack', 'terrorist attack'}, 'AP880517-0226': {'wit', 'rescu crew', 'victim', 'crash site', 'single-engin airplan', 'crumpl airplan', 'albuquerqu', 'investig'}, 'AP880520-0264': {'yugoslavia', 'communist govern', 'ministri statement', 'foreign-back conspiraci', 'polit dissid', 'feder militari command', 'slovenian communist', 'slovenia polic', 'dissid tendenc'}, 'AP880601-0040': {'typic atlant hurrican season', 'coastal counti', 'goes-west', 'first tropic depress', 'forecast', 'nation hurrican center', 'hurrican', 'u.s. death toll', 'hurrican coastal flood model', 'hurricane-forc wind', 'atlant storm season'}, 'AP880613-0161': {'top militari leader', 'osman morot', "morote' captur", 'radic leader', 'shine path movement', 'eight-year guerrilla war', 'counterinsurg polic', 'maoist rebel group', 'peru'}, 'AP880623-0135': {'lawmak', 'illeg alien', 'hous seat', 'repres', 'u.s. constitut', 'censu bureau'}, 'AP880629-0159': {'u.s. air forc', 'f-16', 'crash', 'train mission', 'aircraft', 'bodenheim', 'f-16 fighter jet', 'in-flight crash', 'pilot'}, 'AP880630-0295': {'action list', 'drought panel', 'conserv reserv program', 'usda drought task forc', 'emerg relief measur', 'drought aid', 'drought-rel action', 'congression drought relief task forc', 'meat purchas', 'agricultur depart'}, 'AP880705-0006': {'utah', 'forest fire', 'firefight', 'lightning-spark fire', 'fire line', 'zion nation park', 'brush fire'}, 'AP880705-0018': {'wildfir', 'blaze', 'forest fire', 'illeg firework', 'firefight', 'wyom', 'steadi rain'}, 'AP880705-0109': {'fire', 'wildfir', 'blaze', 'nation forest', 'illeg firework', 'firefight'}, 'AP880714-0142': {'extrem drought', 'nation weather Servic', 'long-term drought condit', 'drought region', 'short-rang forecast', 'dri weather', 'water shortag', 'northern great plain', 'littl relief', 'western great lake region', 'agricultur depart'}, 'AP880801-0195': {'forest fire', 'arsonist', 'pass truck', 'crimin investig', 'arson problem', 'investig', 'missouri'}, 'AP880811-0299': {'total U.S. crop product', 'disast relief bill', 'higher retail food price', 'deaden drought', 'annual agricultur depart survey', 'food product', 'fall corn harvest', 'food price increas', 'sharp reduct', 'presid reagan'}, 'AP880816-0234': {'district attorney carlo escobar', 'polic post', 'osman morot', 'properti damag', 'shine path guerrilla', 'rodrigo franco command', 'rebel raid', 'death squad'}, 'AP880901-0052': {'forest fire develop', 'firefight', 'western state'}, 'AP880902-0062': {'northern japan', 'crash', 'u.s. air base', 'u.s. aircraft', 'f-16c', 'misawa', 'militari jet', 'pilot'}, 'AP880903-0092': {'work requir', 'welfar program', 'unemploy', 'american', 'welfar legisl', 'presid reagan', 'welfar reform'}, 'AP880913-0129': {'navi aviat', 'injuri', 'atlant accid', 'f-14 jet fighter', 'f-14 crash', 'navi aircraft', 'atlant ocean' ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-210e2e9b3f3b> in <module>
#       7     # filter good keyphrases
#       8     ref_a = load_n_flatten_set(get_ref_path(d))
# ----> 9     good_kp_a = {key: value & ref_a[key] for key, value in kp_a[10].items()}
#      10     bad_kp_a = {key: value - ref_a[key] for key, value in kp_a[10].items()}
#      11
#
# <ipython-input-46-210e2e9b3f3b> in <dictcomp>(.0)
#       7     # filter good keyphrases
#       8     ref_a = load_n_flatten_set(get_ref_path(d))
# ----> 9     good_kp_a = {key: value & ref_a[key] for key, value in kp_a[10].items()}
#      10     bad_kp_a = {key: value - ref_a[key] for key, value in kp_a[10].items()}
#      11
#
# KeyError: 'AP830325-0143'

# %%
# Create DataFrame
cols = ['dataset', 'method_a', 'method_b', 'nb_doc', 'inter5', 'inter10',
        'rappel5', 'rappel10', 'good_inter', 'bad_inter']


df = pd.DataFrame(data, columns=cols)
# Init dataframe
df['int_per_doc'] = df['inter'] / df['nb_doc']
df['type'] = ''
df.loc[df['dataset'].isin(['DUC-2001', '500N-KPCrowd', 'NYTime']),'type'] = 'news'
df.loc[df['dataset'].isin(['Inspec', 'WWW', 'KP20k']),'type'] = 'abstract'
df.loc[df['dataset'].isin(['PubMed', 'ACM', 'SemEval-2010']),'type'] = 'full'
map_method = {'MultipartiteRank': 'MPRank', 'CopyCorrRNN': 'CorrRNN', 'CopyCorrRNN_News': 'CorrRNN_News'}
df['method_a'] = df['method_a'].apply(lambda x: map_method.get(x, x))
df['method_b'] = df['method_b'].apply(lambda x: map_method.get(x, x))
df.to_csv('cache.csv')

# %%
disp_methods = [
    'EmbedRank','TextRank', 'PositionRank',
    'Kea', 'FirstPhrases', 'MPRank', 'TfIdf',
    'CopyRNN', 'CorrRNN']
fig = display_heatmap(df, disp_methods)

# %%
full_methods = [
    'TextRank', 'EmbedRank', 'PositionRank',
    'FirstPhrases', 'MPRank', 'Kea',  'TfIdf',
    'CopyRNN', 'CorrRNN']
display_heatmap(df[df['type'] == 'full'], full_methods)

# %%
abstract_methods = [
    'TextRank', 'EmbedRank','PositionRank',
    'FirstPhrases', 'MPRank', 'Kea', 'TfIdf', 
    'CopyRNN', 'CorrRNN']
display_heatmap(df[df['type'] == 'abstract'], abstract_methods)

# %%
news_methods = [
    'TextRank', 'EmbedRank', 'PositionRank','FirstPhrases', 
     #'TfIdf', 'Kea','MPRank',
    'MPRank','Kea', 'TfIdf', 
    'CopyRNN', 'CorrRNN']
display_heatmap(df[df['type'] == 'news'], news_methods)

# %%
# Remove CopyRNN and CorrRNN for News dataset and News version for non news dataset
df4 = df.drop(df[
    ((df['type'] == 'news') & (
        (df['method_a'].isin(['CopyRNN', 'CorrRNN'])) |
        (df['method_b'].isin(['CopyRNN', 'CorrRNN']))
    )) | ((df['type'] != 'news') & (
        (df['method_a'].isin(['CopyRNN_News', 'CorrRNN_News'])) |
        (df['method_b'].isin(['CopyRNN_News', 'CorrRNN_News']))
    ))].index)
df4['method_a'] = df4['method_a'].apply(lambda x: x.replace('_News', ''))
df4['method_b'] = df4['method_b'].apply(lambda x: x.replace('_News', ''))

# %%
fig = plt.figure()
ax = fig.add_subplot(131)
display_heatmap(df4[df4['type'] == 'full'], full_methods, vmin=0.001, vmax=8, cbar=False, ax=ax)
ax.set_title('Scientific articles', fontsize=10, weight='ultralight')
ax = fig.add_subplot(132)
display_heatmap(df4[df4['type'] == 'abstract'], abstract_methods, vmin=0.001, vmax=8, cbar=False, ax=ax)
ax.set_title('Paper abstracts', fontsize=10)
new_ax = fig.add_axes([1, 0.36, .01, .28])
ax = fig.add_subplot(133)
display_heatmap(df4[df4['type'] == 'news'], news_methods, vmin=0.001, vmax=8, cbar=True, ax=ax, cbar_ax=new_ax)
ax.set_title('News articles', fontsize=10)
new_ax.tick_params(labelsize=5)
plt.tight_layout()
plt.savefig('../../../../Downloads/intersect.png', dpi=1080, bbox_inches='tight', transparent=True)

# %% [markdown]
# ### Compute intersect between GOOD keyphrase
# To see which models make the same good thing

# %%
# Create DataFrame
cols = ['dataset', 'method_a', 'method_b', 'nb_doc', 'inter', 'good_inter', 'bad_inter']
df_pos = pd.DataFrame(data, columns=cols)
# Init dataframe
df_pos['inter_per_doc'] = df_pos['inter'] / df_pos['nb_doc']
df_pos['good_inter_per_doc'] = df_pos['good_inter'] / df_pos['nb_doc']
df_pos['bad_inter_per_doc'] = df_pos['bad_inter'] / df_pos['nb_doc']
df_pos['type'] = ''
df_pos.loc[df_pos['dataset'].isin(['DUC-2001', '500N-KPCrowd', 'NYTime']),'type'] = 'news'
df_pos.loc[df_pos['dataset'].isin(['Inspec', 'WWW', 'KP20k']),'type'] = 'abstract'
df_pos.loc[df_pos['dataset'].isin(['PubMed', 'ACM', 'SemEval-2010']),'type'] = 'full'

# %% [markdown]
# ##### @5

# %%
disp_methods = [
    'EmbedRank','TextRank', 'PositionRank',
    'Kea', 'FirstPhrases', 'MultipartiteRank', 'TfIdf',
    'CopyRNN', 'CopyCorrRNN', 'CopyRNN_News', 'CopyCorrRNN_News']
display_heatmap(df_pos, disp_methods, value='good_inter_per_doc')

# %%
full_methods = [
    'TextRank', 'PositionRank','EmbedRank',
    'FirstPhrases', 'MultipartiteRank', 'Kea',  'TfIdf',
    'CopyRNN', 'CopyCorrRNN']
display_heatmap(df_pos[df_pos['type'] == 'full'], full_methods, value='good_inter_per_doc')

# %%
abstract_methods = [
    'TextRank', 'EmbedRank','PositionRank',
     'TfIdf', 'Kea', 'FirstPhrases', 'MultipartiteRank',
    'CopyRNN', 'CopyCorrRNN']
display_heatmap(df_pos[df_pos['type'] == 'abstract'], abstract_methods, value='good_inter_per_doc')

# %%
news_methods = [
    'TextRank', 'EmbedRank', 'PositionRank','FirstPhrases', 
     'TfIdf', 'Kea','MultipartiteRank',
    'CopyRNN_News', 'CopyCorrRNN_News']
display_heatmap(df_pos[df_pos['type'] == 'news'], news_methods, value='good_inter_per_doc')

# %% [markdown]
# ##### @10

# %%
disp_methods = [
    'EmbedRank','TextRank', 'PositionRank',
    'Kea', 'FirstPhrases', 'MultipartiteRank', 'TfIdf',
    'CopyRNN', 'CopyCorrRNN', 'CopyRNN_News', 'CopyCorrRNN_News']
display_heatmap(df_pos, disp_methods, value='good_inter_per_doc')

# %%
full_methods = [
    'TextRank', 'PositionRank','EmbedRank',
    'FirstPhrases', 'MultipartiteRank', 'Kea',  'TfIdf',
    'CopyRNN', 'CopyCorrRNN']
display_heatmap(df_pos[df_pos['type'] == 'full'], full_methods, value='good_inter_per_doc')

# %%
abstract_methods = [
    'TextRank', 'EmbedRank','PositionRank',
     'TfIdf', 'Kea', 'FirstPhrases', 'MultipartiteRank',
    'CopyRNN', 'CopyCorrRNN']
display_heatmap(df_pos[df_pos['type'] == 'abstract'], abstract_methods, value='good_inter_per_doc')

# %%
news_methods = [
    'TextRank', 'EmbedRank', 'PositionRank','FirstPhrases', 
     'TfIdf', 'Kea','MultipartiteRank',
    'CopyRNN_News', 'CopyCorrRNN_News']
display_heatmap(df_pos[df_pos['type'] == 'news'], news_methods, value='good_inter_per_doc')

# %% [markdown]
# ### Compute intersect between BAD keyphrase
# To see which models make the same mistakes

# %%
disp_methods = [
    'EmbedRank','TextRank', 'PositionRank',
    'Kea', 'FirstPhrases', 'MultipartiteRank', 'TfIdf',
    'CopyRNN', 'CopyCorrRNN', 'CopyRNN_News', 'CopyCorrRNN_News']
display_heatmap(df_pos, disp_methods, value='bad_inter_per_doc')

# %%
full_methods = [
    'TextRank', 'PositionRank','EmbedRank',
    'FirstPhrases', 'MultipartiteRank', 'Kea',  'TfIdf',
    'CopyRNN', 'CopyCorrRNN']
display_heatmap(df_pos[df_pos['type'] == 'full'], full_methods, value='bad_inter_per_doc')

# %%
abstract_methods = [
    'TextRank', 'EmbedRank','PositionRank',
     'TfIdf', 'Kea', 'FirstPhrases', 'MultipartiteRank',
    'CopyRNN', 'CopyCorrRNN']
display_heatmap(df_pos[df_pos['type'] == 'abstract'], abstract_methods, value='bad_inter_per_doc')

# %%
news_methods = [
    'TextRank', 'EmbedRank', 'PositionRank','FirstPhrases', 
     'TfIdf', 'Kea','MultipartiteRank',
    'CopyRNN_News', 'CopyCorrRNN_News']
display_heatmap(df_pos[df_pos['type'] == 'news'], news_methods, value='bad_inter_per_doc')
