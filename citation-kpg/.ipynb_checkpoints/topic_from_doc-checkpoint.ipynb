# %% [markdown]
# Le but ici est de créer un référence (requêtes x document).
# Idée de requête
# - Utiliser le titre comme requête
# - Utiliser les noun phrase du titre
# - Les phrases citantes pour retrouver l'article cité
#
# Cas possibles
# - 1 req = 1 doc : très forte correlation entre topic et doc
# - x req = 1 doc
#
# Si 1 req = 1 doc alors il faut que les TC généré soient égal à la requête et en même temps différent des autres requetes, si il y a des requetes proches alors il faudra s'en éloigner donc peut-être
# Si 1 req = X doc
#
# Ces couples (requête x document) vont être utilisés dans une loss.
# L'idée est que grâce aux TC l'accuracy de RI doit augmenter.
# L'accuracy serait un truc comme la cross entropy de la proba que le doc appartienne à la requete ou pas.
# Est-ce que c'est dérivable si c'est à base de : est-ce que les termes de la requete sont dans les TC
# Mais si c'est à base de cosine ça peut être ok, MAIS CONNE lors de l'entrainement on a pas de beam search, donc on sais pas quels sont les TC choisis.

# %%
import json
import spacy
import matplotlib.pyplot as plt
import nltk
from tqdm import tqdm
nlp = spacy.load('en')
stopwords = nltk.corpus.stopwords.words('english')

# %%
with open('../../data/datasets/KP20k/full/kp20k.valid.json') as f:
    data = map(json.loads, f)
    data = {d['id']: d for d in data}

# %% [markdown]
# Topics are the noun chunk extracted from the title of the doc (tokenized on space)
# The abstract and keyword are indexed.
# The relevance score is how many token of topics appear (exactly) in the document.

# %%
# %%time
topics = {k: [t
              for nc in nlp(v['title']).noun_chunks
              for t in nc.text.split() if t.lower() not in stopwords]
          for k, v in list(data.items())}
# Out:
# CPU times: user 2min 8s, sys: 164 ms, total: 2min 8s
# Wall time: 2min 8s

# %%
def relevance_score(doc, topic):
    if not topic:
        return 0
    return sum(t.lower() in doc.lower() for t in topic) / len(topic)

# %%
def doc2content(doc):
    return doc['abstract'] + ' ' + ' '.join(t for k in doc['keyword'].split(';') for t in k.split())

# %%
doc2content(data['020000'])
# Out:
# 'We investigate the problem of delay constrained maximal information collection for CSMA-based wireless sensor networks. We study how to allocate the maximal allowable transmission delay at each node, such that the amount of information collected at the sink is maximized and the total delay for the data aggregation is within the given bound. We formulate the problem by using dynamic programming and propose an optimal algorithm for the optimal assignment of transmission attempts. Based on the analysis of the optimal solution, we propose a distributed greedy algorithm. It is shown to have a similar performance as the optimal one. algorithms design performance sensor networks data aggregation real-time traffic csma/ca delay constrained transmission'

# %%
# %%time
query2relevance = {}
for k, t in tqdm(topics.items()):
    tmp = ((kd, relevance_score(doc2content(d), t)) for kd, d in data.items())
    query2relevance[k] = [(k, s) for k, s in tmp if s >= 0.6]
# Out:
# 100%|██████████| 20000/20000 [1:24:30<00:00,  3.94it/s]
# CPU times: user 1h 24min 26s, sys: 11 s, total: 1h 24min 37s
# Wall time: 1h 24min 30s

# %%
# Requêtes qui retournent trop de résultat

# %%
tmp = {k: (len(topics[k]), len({kd: s for kd, s in t.items() if s > 0.7}))
       for k, t in query2relevance.items()}
[(k, b, topics[k]) for k, (a, b) in tmp.items() if b > 150]
# Out:
# []

# %%
sorted(query2relevance['020006'].items(), reverse=True, key=lambda x: x[1][1])
# Out:
# [('020006', (7, 0.7)),
#  ('023859', (7, 0.7)),
#  ('023424', (5, 0.5)),
#  ('039255', (5, 0.5)),
#  ('022156', (4, 0.4)),
#  ('022754', (4, 0.4)),
#  ('023432', (4, 0.4)),
#  ('024100', (4, 0.4)),
#  ('024387', (4, 0.4)),
#  ('024911', (4, 0.4)),
#  ('025031', (4, 0.4)),
#  ('025480', (4, 0.4)),
#  ('026119', (4, 0.4)),
#  ('026190', (4, 0.4)),
#  ('028326', (4, 0.4)),
#  ('028882', (4, 0.4)),
#  ('028940', (4, 0.4)),
#  ('029137', (4, 0.4)),
#  ('030852', (4, 0.4)),
#  ('034334', (4, 0.4)),
#  ('036020', (4, 0.4)),
#  ('036571', (4, 0.4)),
#  ('036968', (4, 0.4)),
#  ('037129', (4, 0.4)),
#  ('038404', (4, 0.4)),
#  ('039577', (4, 0.4)),
#  ('020314', (3, 0.3)),
#  ('020317', (3, 0.3)),
#  ('021174', (3, 0.3)),
#  ('021257', (3, 0.3)),
#  ('021450', (3, 0.3)),
#  ('021795', (3, 0.3)),
#  ('021852', (3, 0.3)),
#  ('022006', (3, 0.3)),
#  ('022009', (3, 0.3)),
#  ('022136', (3, 0.3)),
#  ('022270', (3, 0.3)),
#  ('022402', (3, 0.3)),
#  ('022480', (3, 0.3)),
#  ('022566', (3, 0.3)),
#  ('022578', (3, 0.3)),
#  ('023121', (3, 0.3)),
#  ('023295', (3, 0.3)),
#  ('023350', (3, 0.3)),
#  ('023616', (3, 0.3)),
#  ('023617', (3, 0.3)),
#  ('023673', (3, 0.3)),
#  ('023819', (3, 0.3)),
#  ('023896', (3, 0.3)),
#  ('024273', (3, 0.3)),
#  ('024274', (3, 0.3)),
#  ('024405', (3, 0.3)),
#  ('024546', (3, 0.3)),
#  ('024559', (3, 0.3)),
#  ('024673', (3, 0.3)),
#  ('024928', (3, 0.3)),
#  ('024948', (3, 0.3)),
#  ('025033', (3, 0.3)),
#  ('025179', (3, 0.3)),
#  ('026221', (3, 0.3)),
#  ('026897', (3, 0.3)),
#  ('026901', (3, 0.3)),
#  ('026911', (3, 0.3)),
#  ('027118', (3, 0.3)),
#  ('027633', (3, 0.3)),
#  ('027836', (3, 0.3)),
#  ('027977', (3, 0.3)),
#  ('028206', (3, 0.3)),
#  ('028332', (3, 0.3)),
#  ('028440', (3, 0.3)),
#  ('028508', (3, 0.3)),
#  ('028942', (3, 0.3)),
#  ('028961', (3, 0.3)),
#  ('029333', (3, 0.3)),
#  ('029366', (3, 0.3)),
#  ('029721', (3, 0.3)),
#  ('029848', (3, 0.3)),
#  ('030148', (3, 0.3)),
#  ('030820', (3, 0.3)),
#  ('031033', (3, 0.3)),
#  ('031322', (3, 0.3)),
#  ('031627', (3, 0.3)),
#  ('031770', (3, 0.3)),
#  ('031851', (3, 0.3)),
#  ('031900', (3, 0.3)),
#  ('032000', (3, 0.3)),
#  ('032075', (3, 0.3)),
#  ('032121', (3, 0.3)),
#  ('032827', (3, 0.3)),
#  ('032838', (3, 0.3)),
#  ('033116', (3, 0.3)),
#  ('033192', (3, 0.3)),
#  ('033599', (3, 0.3)),
#  ('033627', (3, 0.3)),
#  ('033721', (3, 0.3)),
#  ('033807', (3, 0.3)),
#  ('033852', (3, 0.3)),
#  ('033859', (3, 0.3)),
#  ('034054', (3, 0.3)),
#  ('034124', (3, 0.3)),
#  ('034237', (3, 0.3)),
#  ('034824', (3, 0.3)),
#  ('035055', (3, 0.3)),
#  ('035080', (3, 0.3)),
#  ('035558', (3, 0.3)),
#  ('036045', (3, 0.3)),
#  ('036232', (3, 0.3)),
#  ('036672', (3, 0.3)),
#  ('036786', (3, 0.3)),
#  ('037100', (3, 0.3)),
#  ('037139', (3, 0.3)),
#  ('037226', (3, 0.3)),
#  ('037313', (3, 0.3)),
#  ('037546', (3, 0.3)),
#  ('037629', (3, 0.3)),
#  ('037886', (3, 0.3)),
#  ('037988', (3, 0.3)),
#  ('038520', (3, 0.3)),
#  ('038651', (3, 0.3)),
#  ('038699', (3, 0.3)),
#  ('039131', (3, 0.3)),
#  ('039303', (3, 0.3)),
#  ('020032', (2, 0.2)),
#  ('020063', (2, 0.2)),
#  ('020090', (2, 0.2)),
#  ('020106', (2, 0.2)),
#  ('020124', (2, 0.2)),
#  ('020150', (2, 0.2)),
#  ('020153', (2, 0.2)),
#  ('020212', (2, 0.2)),
#  ('020231', (2, 0.2)),
#  ('020278', (2, 0.2)),
#  ('020305', (2, 0.2)),
#  ('020358', (2, 0.2)),
#  ('020409', (2, 0.2)),
#  ('020413', (2, 0.2)),
#  ('020471', (2, 0.2)),
#  ('020476', (2, 0.2)),
#  ('020479', (2, 0.2)),
#  ('020487', (2, 0.2)),
#  ('020511', (2, 0.2)),
#  ('020517', (2, 0.2)),
#  ('020521', (2, 0.2)),
#  ('020533', (2, 0.2)),
#  ('020548', (2, 0.2)),
#  ('020560', (2, 0.2)),
#  ('020578', (2, 0.2)),
#  ('020595', (2, 0.2)),
#  ('020604', (2, 0.2)),
#  ('020638', (2, 0.2)),
#  ('020646', (2, 0.2)),
#  ('020659', (2, 0.2)),
#  ('020720', (2, 0.2)),
#  ('020764', (2, 0.2)),
#  ('020792', (2, 0.2)),
#  ('020793', (2, 0.2)),
#  ('020807', (2, 0.2)),
#  ('020901', (2, 0.2)),
#  ('020948', (2, 0.2)),
#  ('020981', (2, 0.2)),
#  ('021087', (2, 0.2)),
#  ('021145', (2, 0.2)),
#  ('021182', (2, 0.2)),
#  ('021202', (2, 0.2)),
#  ('021215', (2, 0.2)),
#  ('021233', (2, 0.2)),
#  ('021240', (2, 0.2)),
#  ('021260', (2, 0.2)),
#  ('021297', (2, 0.2)),
#  ('021350', (2, 0.2)),
#  ('021351', (2, 0.2)),
#  ('021392', (2, 0.2)),
#  ('021503', (2, 0.2)),
#  ('021523', (2, 0.2)),
#  ('021567', (2, 0.2)),
#  ('021595', (2, 0.2)),
#  ('021613', (2, 0.2)),
#  ('021658', (2, 0.2)),
#  ('021689', (2, 0.2)),
#  ('021715', (2, 0.2)),
#  ('021796', (2, 0.2)),
#  ('021804', (2, 0.2)),
#  ('021849', (2, 0.2)),
#  ('021868', (2, 0.2)),
#  ('021869', (2, 0.2)),
#  ('021886', (2, 0.2)),
#  ('021902', (2, 0.2)),
#  ('021959', (2, 0.2)),
#  ('022030', (2, 0.2)),
#  ('022065', (2, 0.2)),
#  ('022096', (2, 0.2)),
#  ('022102', (2, 0.2)),
#  ('022139', (2, 0.2)),
#  ('022174', (2, 0.2)),
#  ('022223', (2, 0.2)),
#  ('022246', (2, 0.2)),
#  ('022257', (2, 0.2)),
#  ('022260', (2, 0.2)),
#  ('022266', (2, 0.2)),
#  ('022292', (2, 0.2)),
#  ('022300', (2, 0.2)),
#  ('022305', (2, 0.2)),
#  ('022344', (2, 0.2)),
#  ('022348', (2, 0.2)),
#  ('022369', (2, 0.2)),
#  ('022433', (2, 0.2)),
#  ('022454', (2, 0.2)),
#  ('022492', (2, 0.2)),
#  ('022536', (2, 0.2)),
#  ('022581', (2, 0.2)),
#  ('022628', (2, 0.2)),
#  ('022680', (2, 0.2)),
#  ('022696', (2, 0.2)),
#  ('022763', (2, 0.2)),
#  ('022780', (2, 0.2)),
#  ('022803', (2, 0.2)),
#  ('022812', (2, 0.2)),
#  ('022845', (2, 0.2)),
#  ('022846', (2, 0.2)),
#  ('022885', (2, 0.2)),
#  ('022925', (2, 0.2)),
#  ('022927', (2, 0.2)),
#  ('022947', (2, 0.2)),
#  ('022952', (2, 0.2)),
#  ('022954', (2, 0.2)),
#  ('022957', (2, 0.2)),
#  ('022959', (2, 0.2)),
#  ('022971', (2, 0.2)),
#  ('023033', (2, 0.2)),
#  ('023088', (2, 0.2)),
#  ('023091', (2, 0.2)),
#  ('023101', (2, 0.2)),
#  ('023160', (2, 0.2)),
#  ('023164', (2, 0.2)),
#  ('023183', (2, 0.2)),
#  ('023213', (2, 0.2)),
#  ('023215', (2, 0.2)),
#  ('023216', (2, 0.2)),
#  ('023318', (2, 0.2)),
#  ('023435', (2, 0.2)),
#  ('023468', (2, 0.2)),
#  ('023475', (2, 0.2)),
#  ('023497', (2, 0.2)),
#  ('023506', (2, 0.2)),
#  ('023576', (2, 0.2)),
#  ('023615', (2, 0.2)),
#  ('023706', (2, 0.2)),
#  ('023713', (2, 0.2)),
#  ('023773', (2, 0.2)),
#  ('023837', (2, 0.2)),
#  ('023871', (2, 0.2)),
#  ('023930', (2, 0.2)),
#  ('023937', (2, 0.2)),
#  ('024006', (2, 0.2)),
#  ('024055', (2, 0.2)),
#  ('024067', (2, 0.2)),
#  ('024219', (2, 0.2)),
#  ('024229', (2, 0.2)),
#  ('024331', (2, 0.2)),
#  ('024407', (2, 0.2)),
#  ('024416', (2, 0.2)),
#  ('024439', (2, 0.2)),
#  ('024472', (2, 0.2)),
#  ('024497', (2, 0.2)),
#  ('024540', (2, 0.2)),
#  ('024566', (2, 0.2)),
#  ('024578', (2, 0.2)),
#  ('024633', (2, 0.2)),
#  ('024659', (2, 0.2)),
#  ('024696', (2, 0.2)),
#  ('024711', (2, 0.2)),
#  ('024757', (2, 0.2)),
#  ('024771', (2, 0.2)),
#  ('024782', (2, 0.2)),
#  ('024803', (2, 0.2)),
#  ('024828', (2, 0.2)),
#  ('024845', (2, 0.2)),
#  ('024860', (2, 0.2)),
#  ('024861', (2, 0.2)),
#  ('024866', (2, 0.2)),
#  ('025000', (2, 0.2)),
#  ('025001', (2, 0.2)),
#  ('025026', (2, 0.2)),
#  ('025067', (2, 0.2)),
#  ('025091', (2, 0.2)),
#  ('025096', (2, 0.2)),
#  ('025140', (2, 0.2)),
#  ('025181', (2, 0.2)),
#  ('025207', (2, 0.2)),
#  ('025226', (2, 0.2)),
#  ('025261', (2, 0.2)),
#  ('025333', (2, 0.2)),
#  ('025372', (2, 0.2)),
#  ('025417', (2, 0.2)),
#  ('025434', (2, 0.2)),
#  ('025463', (2, 0.2)),
#  ('025502', (2, 0.2)),
#  ('025545', (2, 0.2)),
#  ('025561', (2, 0.2)),
#  ('025580', (2, 0.2)),
#  ('025695', (2, 0.2)),
#  ('025696', (2, 0.2)),
#  ('025764', (2, 0.2)),
#  ('025802', (2, 0.2)),
#  ('025807', (2, 0.2)),
#  ('025869', (2, 0.2)),
#  ('025885', (2, 0.2)),
#  ('025906', (2, 0.2)),
#  ('025912', (2, 0.2)),
#  ('025944', (2, 0.2)),
#  ('026016', (2, 0.2)),
#  ('026034', (2, 0.2)),
#  ('026038', (2, 0.2)),
#  ('026041', (2, 0.2)),
#  ('026054', (2, 0.2)),
#  ('026078', (2, 0.2)),
#  ('026101', (2, 0.2)),
#  ('026113', (2, 0.2)),
#  ('026129', (2, 0.2)),
#  ('026192', (2, 0.2)),
#  ('026195', (2, 0.2)),
#  ('026231', (2, 0.2)),
#  ('026242', (2, 0.2)),
#  ('026247', (2, 0.2)),
#  ('026269', (2, 0.2)),
#  ('026286', (2, 0.2)),
#  ('026390', (2, 0.2)),
#  ('026447', (2, 0.2)),
#  ('026559', (2, 0.2)),
#  ('026561', (2, 0.2)),
#  ('026593', (2, 0.2)),
#  ('026641', (2, 0.2)),
#  ('026696', (2, 0.2)),
#  ('026725', (2, 0.2)),
#  ('026829', (2, 0.2)),
#  ('026832', (2, 0.2)),
#  ('026870', (2, 0.2)),
#  ('026882', (2, 0.2)),
#  ('026891', (2, 0.2)),
#  ('026937', (2, 0.2)),
#  ('026942', (2, 0.2)),
#  ('026987', (2, 0.2)),
#  ('027049', (2, 0.2)),
#  ('027082', (2, 0.2)),
#  ('027143', (2, 0.2)),
#  ('027160', (2, 0.2)),
#  ('027164', (2, 0.2)),
#  ('027188', (2, 0.2)),
#  ('027235', (2, 0.2)),
#  ('027263', (2, 0.2)),
#  ('027326', (2, 0.2)),
#  ('027330', (2, 0.2)),
#  ('027412', (2, 0.2)),
#  ('027451', (2, 0.2)),
#  ('027478', (2, 0.2)),
#  ('027570', (2, 0.2)),
#  ('027589', (2, 0.2)),
#  ('027608', (2, 0.2)),
#  ('027625', (2, 0.2)),
#  ('027710', (2, 0.2)),
#  ('027715', (2, 0.2)),
#  ('027721', (2, 0.2)),
#  ('027757', (2, 0.2)),
#  ('027764', (2, 0.2)),
#  ('027795', (2, 0.2)),
#  ('027814', (2, 0.2)),
#  ('027817', (2, 0.2)),
#  ('027862', (2, 0.2)),
#  ('027883', (2, 0.2)),
#  ('027927', (2, 0.2)),
#  ('027939', (2, 0.2)),
#  ('028011', (2, 0.2)),
#  ('028032', (2, 0.2)),
#  ('028043', (2, 0.2)),
#  ('028104', (2, 0.2)),
#  ('028138', (2, 0.2)),
#  ('028157', (2, 0.2)),
#  ('028267', (2, 0.2)),
#  ('028371', (2, 0.2)),
#  ('028488', (2, 0.2)),
#  ('028538', (2, 0.2)),
#  ('028549', (2, 0.2)),
#  ('028557', (2, 0.2)),
#  ('028672', (2, 0.2)),
#  ('028727', (2, 0.2)),
#  ('028774', (2, 0.2)),
#  ('028816', (2, 0.2)),
#  ('028957', (2, 0.2)),
#  ('028969', (2, 0.2)),
#  ('028972', (2, 0.2)),
#  ('029008', (2, 0.2)),
#  ('029009', (2, 0.2)),
#  ('029026', (2, 0.2)),
#  ('029032', (2, 0.2)),
#  ('029034', (2, 0.2)),
#  ('029050', (2, 0.2)),
#  ('029110', (2, 0.2)),
#  ('029141', (2, 0.2)),
#  ('029143', (2, 0.2)),
#  ('029285', (2, 0.2)),
#  ('029346', (2, 0.2)),
#  ('029434', (2, 0.2)),
#  ('029435', (2, 0.2)),
#  ('029455', (2, 0.2)),
#  ('029460', (2, 0.2)),
#  ('029536', (2, 0.2)),
#  ('029573', (2, 0.2)),
#  ('029589', (2, 0.2)),
#  ('029633', (2, 0.2)),
#  ('029646', (2, 0.2)),
#  ('029661', (2, 0.2)),
#  ('029680', (2, 0.2)),
#  ('029742', (2, 0.2)),
#  ('029779', (2, 0.2)),
#  ('029785', (2, 0.2)),
#  ('029845', (2, 0.2)),
#  ('029860', (2, 0.2)),
#  ('029871', (2, 0.2)),
#  ('029873', (2, 0.2)),
#  ('029891', (2, 0.2)),
#  ('029907', (2, 0.2)),
#  ('029940', (2, 0.2)),
#  ('029978', (2, 0.2)),
#  ('030001', (2, 0.2)),
#  ('030015', (2, 0.2)),
#  ('030028', (2, 0.2)),
#  ('030030', (2, 0.2)),
#  ('030055', (2, 0.2)),
#  ('030108', (2, 0.2)),
#  ('030130', (2, 0.2)),
#  ('030158', (2, 0.2)),
#  ('030166', (2, 0.2)),
#  ('030184', (2, 0.2)),
#  ('030191', (2, 0.2)),
#  ('030200', (2, 0.2)),
#  ('030218', (2, 0.2)),
#  ('030228', (2, 0.2)),
#  ('030281', (2, 0.2)),
#  ('030300', (2, 0.2)),
#  ('030306', (2, 0.2)),
#  ('030324', (2, 0.2)),
#  ('030441', (2, 0.2)),
#  ('030457', (2, 0.2)),
#  ('030461', (2, 0.2)),
#  ('030472', (2, 0.2)),
#  ('030481', (2, 0.2)),
#  ('030558', (2, 0.2)),
#  ('030586', (2, 0.2)),
#  ('030609', (2, 0.2)),
#  ('030653', (2, 0.2)),
#  ('030685', (2, 0.2)),
#  ('030706', (2, 0.2)),
#  ('030724', (2, 0.2)),
#  ('030763', (2, 0.2)),
#  ('030770', (2, 0.2)),
#  ('030812', (2, 0.2)),
#  ('030824', (2, 0.2)),
#  ('030908', (2, 0.2)),
#  ('030909', (2, 0.2)),
#  ('030914', (2, 0.2)),
#  ('030925', (2, 0.2)),
#  ('030932', (2, 0.2)),
#  ('030934', (2, 0.2)),
#  ('030936', (2, 0.2)),
#  ('031031', (2, 0.2)),
#  ('031091', (2, 0.2)),
#  ('031209', (2, 0.2)),
#  ('031237', (2, 0.2)),
#  ('031245', (2, 0.2)),
#  ('031289', (2, 0.2)),
#  ('031364', (2, 0.2)),
#  ('031370', (2, 0.2)),
#  ('031452', (2, 0.2)),
#  ('031555', (2, 0.2)),
#  ('031556', (2, 0.2)),
#  ('031574', (2, 0.2)),
#  ('031587', (2, 0.2)),
#  ('031630', (2, 0.2)),
#  ('031649', (2, 0.2)),
#  ('031684', (2, 0.2)),
#  ('031821', (2, 0.2)),
#  ('031829', (2, 0.2)),
#  ('031844', (2, 0.2)),
#  ('031856', (2, 0.2)),
#  ('031859', (2, 0.2)),
#  ('031870', (2, 0.2)),
#  ('031886', (2, 0.2)),
#  ('031917', (2, 0.2)),
#  ('031991', (2, 0.2)),
#  ('032097', (2, 0.2)),
#  ('032132', (2, 0.2)),
#  ('032133', (2, 0.2)),
#  ('032143', (2, 0.2)),
#  ('032169', (2, 0.2)),
#  ('032236', (2, 0.2)),
#  ('032239', (2, 0.2)),
#  ('032247', (2, 0.2)),
#  ('032306', (2, 0.2)),
#  ('032359', (2, 0.2)),
#  ('032383', (2, 0.2)),
#  ('032398', (2, 0.2)),
#  ('032551', (2, 0.2)),
#  ('032569', (2, 0.2)),
#  ('032575', (2, 0.2)),
#  ('032629', (2, 0.2)),
#  ('032707', (2, 0.2)),
#  ('032734', (2, 0.2)),
#  ('032735', (2, 0.2)),
#  ('032738', (2, 0.2)),
#  ('032750', (2, 0.2)),
#  ('032761', (2, 0.2)),
#  ('032770', (2, 0.2)),
#  ('032772', (2, 0.2)),
#  ('032784', (2, 0.2)),
#  ('032863', (2, 0.2)),
#  ('032913', (2, 0.2)),
#  ('032942', (2, 0.2)),
#  ('032947', (2, 0.2)),
#  ('032956', (2, 0.2)),
#  ('033121', (2, 0.2)),
#  ('033157', (2, 0.2)),
#  ('033172', (2, 0.2)),
#  ('033178', (2, 0.2)),
#  ('033203', (2, 0.2)),
#  ('033221', (2, 0.2)),
#  ('033272', (2, 0.2)),
#  ('033275', (2, 0.2)),
#  ('033319', (2, 0.2)),
#  ('033329', (2, 0.2)),
#  ('033340', (2, 0.2)),
#  ('033347', (2, 0.2)),
#  ('033360', (2, 0.2)),
#  ('033394', (2, 0.2)),
#  ('033410', (2, 0.2)),
#  ('033428', (2, 0.2)),
#  ('033429', (2, 0.2)),
#  ('033432', (2, 0.2)),
#  ('033502', (2, 0.2)),
#  ('033536', (2, 0.2)),
#  ('033560', (2, 0.2)),
#  ('033579', (2, 0.2)),
#  ('033700', (2, 0.2)),
#  ('033716', (2, 0.2)),
#  ('033841', (2, 0.2)),
#  ('033886', (2, 0.2)),
#  ('033900', (2, 0.2)),
#  ('033923', (2, 0.2)),
#  ('033953', (2, 0.2)),
#  ('034022', (2, 0.2)),
#  ('034034', (2, 0.2)),
#  ('034042', (2, 0.2)),
#  ('034050', (2, 0.2)),
#  ('034060', (2, 0.2)),
#  ('034108', (2, 0.2)),
#  ('034143', (2, 0.2)),
#  ('034158', (2, 0.2)),
#  ('034190', (2, 0.2)),
#  ('034215', (2, 0.2)),
#  ('034294', (2, 0.2)),
#  ('034311', (2, 0.2)),
#  ('034333', (2, 0.2)),
#  ('034397', (2, 0.2)),
#  ('034417', (2, 0.2)),
#  ('034429', (2, 0.2)),
#  ('034432', (2, 0.2)),
#  ('034477', (2, 0.2)),
#  ('034553', (2, 0.2)),
#  ('034567', (2, 0.2)),
#  ('034574', (2, 0.2)),
#  ('034587', (2, 0.2)),
#  ('034595', (2, 0.2)),
#  ('034600', (2, 0.2)),
#  ('034636', (2, 0.2)),
#  ('034719', (2, 0.2)),
#  ('034728', (2, 0.2)),
#  ('034756', (2, 0.2)),
#  ('034790', (2, 0.2)),
#  ('034820', (2, 0.2)),
#  ('034822', (2, 0.2)),
#  ('034866', (2, 0.2)),
#  ('034868', (2, 0.2)),
#  ('034873', (2, 0.2)),
#  ('034899', (2, 0.2)),
#  ('034912', (2, 0.2)),
#  ('034931', (2, 0.2)),
#  ('034945', (2, 0.2)),
#  ('034998', (2, 0.2)),
#  ('035008', (2, 0.2)),
#  ('035077', (2, 0.2)),
#  ('035108', (2, 0.2)),
#  ('035110', (2, 0.2)),
#  ('035127', (2, 0.2)),
#  ('035133', (2, 0.2)),
#  ('035139', (2, 0.2)),
#  ('035167', (2, 0.2)),
#  ('035185', (2, 0.2)),
#  ('035215', (2, 0.2)),
#  ('035249', (2, 0.2)),
#  ('035258', (2, 0.2)),
#  ('035280', (2, 0.2)),
#  ('035304', (2, 0.2)),
#  ('035310', (2, 0.2)),
#  ('035343', (2, 0.2)),
#  ('035373', (2, 0.2)),
#  ('035418', (2, 0.2)),
#  ('035421', (2, 0.2)),
#  ('035456', (2, 0.2)),
#  ('035474', (2, 0.2)),
#  ('035543', (2, 0.2)),
#  ('035552', (2, 0.2)),
#  ('035590', (2, 0.2)),
#  ('035624', (2, 0.2)),
#  ('035658', (2, 0.2)),
#  ('035670', (2, 0.2)),
#  ('035693', (2, 0.2)),
#  ('035778', (2, 0.2)),
#  ('035827', (2, 0.2)),
#  ('035914', (2, 0.2)),
#  ('035925', (2, 0.2)),
#  ('035968', (2, 0.2)),
#  ('035994', (2, 0.2)),
#  ('036005', (2, 0.2)),
#  ('036051', (2, 0.2)),
#  ('036074', (2, 0.2)),
#  ('036092', (2, 0.2)),
#  ('036134', (2, 0.2)),
#  ('036150', (2, 0.2)),
#  ('036200', (2, 0.2)),
#  ('036246', (2, 0.2)),
#  ('036266', (2, 0.2)),
#  ('036319', (2, 0.2)),
#  ('036354', (2, 0.2)),
#  ('036378', (2, 0.2)),
#  ('036380', (2, 0.2)),
#  ('036384', (2, 0.2)),
#  ('036393', (2, 0.2)),
#  ('036402', (2, 0.2)),
#  ('036420', (2, 0.2)),
#  ('036443', (2, 0.2)),
#  ('036453', (2, 0.2)),
#  ('036465', (2, 0.2)),
#  ('036476', (2, 0.2)),
#  ('036513', (2, 0.2)),
#  ('036547', (2, 0.2)),
#  ('036558', (2, 0.2)),
#  ('036584', (2, 0.2)),
#  ('036620', (2, 0.2)),
#  ('036640', (2, 0.2)),
#  ('036676', (2, 0.2)),
#  ('036711', (2, 0.2)),
#  ('036712', (2, 0.2)),
#  ('036775', (2, 0.2)),
#  ('036797', (2, 0.2)),
#  ('036801', (2, 0.2)),
#  ('036849', (2, 0.2)),
#  ('036884', (2, 0.2)),
#  ('036996', (2, 0.2)),
#  ('037040', (2, 0.2)),
#  ('037069', (2, 0.2)),
#  ('037205', (2, 0.2)),
#  ('037216', (2, 0.2)),
#  ('037236', (2, 0.2)),
#  ('037431', (2, 0.2)),
#  ('037443', (2, 0.2)),
#  ('037460', (2, 0.2)),
#  ('037461', (2, 0.2)),
#  ('037539', (2, 0.2)),
#  ('037597', (2, 0.2)),
#  ('037612', (2, 0.2)),
#  ('037625', (2, 0.2)),
#  ('037648', (2, 0.2)),
#  ('037653', (2, 0.2)),
#  ('037656', (2, 0.2)),
#  ('037673', (2, 0.2)),
#  ('037694', (2, 0.2)),
#  ('037727', (2, 0.2)),
#  ('037731', (2, 0.2)),
#  ('037736', (2, 0.2)),
#  ('037774', (2, 0.2)),
#  ('037790', (2, 0.2)),
#  ('037851', (2, 0.2)),
#  ('037871', (2, 0.2)),
#  ('037907', (2, 0.2)),
#  ('037977', (2, 0.2)),
#  ('037983', (2, 0.2)),
#  ('038094', (2, 0.2)),
#  ('038109', (2, 0.2)),
#  ('038144', (2, 0.2)),
#  ('038225', (2, 0.2)),
#  ('038247', (2, 0.2)),
#  ('038265', (2, 0.2)),
#  ('038374', (2, 0.2)),
#  ('038377', (2, 0.2)),
#  ('038384', (2, 0.2)),
#  ('038405', (2, 0.2)),
#  ('038409', (2, 0.2)),
#  ('038410', (2, 0.2)),
#  ('038626', (2, 0.2)),
#  ('038655', (2, 0.2)),
#  ('038695', (2, 0.2)),
#  ('038768', (2, 0.2)),
#  ('038823', (2, 0.2)),
#  ('038833', (2, 0.2)),
#  ('038867', (2, 0.2)),
#  ('038885', (2, 0.2)),
#  ('038888', (2, 0.2)),
#  ('038891', (2, 0.2)),
#  ('038911', (2, 0.2)),
#  ('038950', (2, 0.2)),
#  ('038977', (2, 0.2)),
#  ('039002', (2, 0.2)),
#  ('039031', (2, 0.2)),
#  ('039057', (2, 0.2)),
#  ('039077', (2, 0.2)),
#  ('039098', (2, 0.2)),
#  ('039195', (2, 0.2)),
#  ('039256', (2, 0.2)),
#  ('039259', (2, 0.2)),
#  ('039349', (2, 0.2)),
#  ('039366', (2, 0.2)),
#  ('039371', (2, 0.2)),
#  ('039394', (2, 0.2)),
#  ('039444', (2, 0.2)),
#  ('039477', (2, 0.2)),
#  ('039498', (2, 0.2)),
#  ('039514', (2, 0.2)),
#  ('039534', (2, 0.2)),
#  ('039557', (2, 0.2)),
#  ('039559', (2, 0.2)),
#  ('039574', (2, 0.2)),
#  ('039576', (2, 0.2)),
#  ('039604', (2, 0.2)),
#  ('039696', (2, 0.2)),
#  ('039716', (2, 0.2)),
#  ('039731', (2, 0.2)),
#  ('039737', (2, 0.2)),
#  ('039741', (2, 0.2)),
#  ('039793', (2, 0.2)),
#  ('039799', (2, 0.2)),
#  ('039808', (2, 0.2)),
#  ('039824', (2, 0.2)),
#  ('039837', (2, 0.2)),
#  ('039856', (2, 0.2)),
#  ('039882', (2, 0.2)),
#  ('039902', (2, 0.2)),
#  ('039905', (2, 0.2)),
#  ('039953', (2, 0.2)),
#  ('039991', (2, 0.2)),
#  ('020002', (1, 0.1)),
#  ('020015', (1, 0.1)),
#  ('020026', (1, 0.1)),
#  ('020030', (1, 0.1)),
#  ('020031', (1, 0.1)),
#  ('020049', (1, 0.1)),
#  ('020054', (1, 0.1)),
#  ('020055', (1, 0.1)),
#  ('020057', (1, 0.1)),
#  ('020067', (1, 0.1)),
#  ('020071', (1, 0.1)),
#  ('020083', (1, 0.1)),
#  ('020091', (1, 0.1)),
#  ('020095', (1, 0.1)),
#  ('020107', (1, 0.1)),
#  ('020129', (1, 0.1)),
#  ('020137', (1, 0.1)),
#  ('020144', (1, 0.1)),
#  ('020156', (1, 0.1)),
#  ('020161', (1, 0.1)),
#  ('020166', (1, 0.1)),
#  ('020177', (1, 0.1)),
#  ('020191', (1, 0.1)),
#  ('020199', (1, 0.1)),
#  ('020205', (1, 0.1)),
#  ('020219', (1, 0.1)),
#  ('020220', (1, 0.1)),
#  ('020223', (1, 0.1)),
#  ('020229', (1, 0.1)),
#  ('020260', (1, 0.1)),
#  ('020293', (1, 0.1)),
#  ('020294', (1, 0.1)),
#  ('020298', (1, 0.1)),
#  ('020300', (1, 0.1)),
#  ('020311', (1, 0.1)),
#  ('020328', (1, 0.1)),
#  ('020330', (1, 0.1)),
#  ('020331', (1, 0.1)),
#  ('020337', (1, 0.1)),
#  ('020349', (1, 0.1)),
#  ('020351', (1, 0.1)),
#  ('020353', (1, 0.1)),
#  ('020356', (1, 0.1)),
#  ('020361', (1, 0.1)),
#  ('020373', (1, 0.1)),
#  ('020377', (1, 0.1)),
#  ('020382', (1, 0.1)),
#  ('020400', (1, 0.1)),
#  ('020422', (1, 0.1)),
#  ('020428', (1, 0.1)),
#  ('020432', (1, 0.1)),
#  ('020433', (1, 0.1)),
#  ('020435', (1, 0.1)),
#  ('020439', (1, 0.1)),
#  ('020464', (1, 0.1)),
#  ('020465', (1, 0.1)),
#  ('020485', (1, 0.1)),
#  ('020486', (1, 0.1)),
#  ('020492', (1, 0.1)),
#  ('020501', (1, 0.1)),
#  ('020508', (1, 0.1)),
#  ('020512', (1, 0.1)),
#  ('020518', (1, 0.1)),
#  ('020531', (1, 0.1)),
#  ('020552', (1, 0.1)),
#  ('020555', (1, 0.1)),
#  ('020563', (1, 0.1)),
#  ('020569', (1, 0.1)),
#  ('020577', (1, 0.1)),
#  ('020594', (1, 0.1)),
#  ('020599', (1, 0.1)),
#  ('020607', (1, 0.1)),
#  ('020613', (1, 0.1)),
#  ('020621', (1, 0.1)),
#  ('020632', (1, 0.1)),
#  ('020635', (1, 0.1)),
#  ('020641', (1, 0.1)),
#  ('020644', (1, 0.1)),
#  ('020647', (1, 0.1)),
#  ('020671', (1, 0.1)),
#  ('020675', (1, 0.1)),
#  ('020694', (1, 0.1)),
#  ('020709', (1, 0.1)),
#  ('020711', (1, 0.1)),
#  ('020719', (1, 0.1)),
#  ('020723', (1, 0.1)),
#  ('020725', (1, 0.1)),
#  ('020726', (1, 0.1)),
#  ('020736', (1, 0.1)),
#  ('020737', (1, 0.1)),
#  ('020741', (1, 0.1)),
#  ('020757', (1, 0.1)),
#  ('020779', (1, 0.1)),
#  ('020800', (1, 0.1)),
#  ('020812', (1, 0.1)),
#  ('020816', (1, 0.1)),
#  ('020819', (1, 0.1)),
#  ('020824', (1, 0.1)),
#  ('020825', (1, 0.1)),
#  ('020832', (1, 0.1)),
#  ('020841', (1, 0.1)),
#  ('020842', (1, 0.1)),
#  ('020848', (1, 0.1)),
#  ('020849', (1, 0.1)),
#  ('020862', (1, 0.1)),
#  ('020865', (1, 0.1)),
#  ('020866', (1, 0.1)),
#  ('020871', (1, 0.1)),
#  ('020887', (1, 0.1)),
#  ('020891', (1, 0.1)),
#  ('020917', (1, 0.1)),
#  ('020922', (1, 0.1)),
#  ('020930', (1, 0.1)),
#  ('020933', (1, 0.1)),
#  ('020937', (1, 0.1)),
#  ('020941', (1, 0.1)),
#  ('020942', (1, 0.1)),
#  ('020945', (1, 0.1)),
#  ('020947', (1, 0.1)),
#  ('020960', (1, 0.1)),
#  ('020965', (1, 0.1)),
#  ('020971', (1, 0.1)),
#  ('020972', (1, 0.1)),
#  ('020991', (1, 0.1)),
#  ('020993', (1, 0.1)),
#  ('021000', (1, 0.1)),
#  ('021005', (1, 0.1)),
#  ('021006', (1, 0.1)),
#  ('021016', (1, 0.1)),
#  ('021019', (1, 0.1)),
#  ('021032', (1, 0.1)),
#  ('021035', (1, 0.1)),
#  ('021045', (1, 0.1)),
#  ('021067', (1, 0.1)),
#  ('021068', (1, 0.1)),
#  ('021076', (1, 0.1)),
#  ('021096', (1, 0.1)),
#  ('021100', (1, 0.1)),
#  ('021102', (1, 0.1)),
#  ('021107', (1, 0.1)),
#  ('021113', (1, 0.1)),
#  ('021117', (1, 0.1)),
#  ('021121', (1, 0.1)),
#  ('021124', (1, 0.1)),
#  ('021129', (1, 0.1)),
#  ('021131', (1, 0.1)),
#  ('021140', (1, 0.1)),
#  ('021144', (1, 0.1)),
#  ('021147', (1, 0.1)),
#  ('021150', (1, 0.1)),
#  ('021151', (1, 0.1)),
#  ('021162', (1, 0.1)),
#  ('021189', (1, 0.1)),
#  ('021198', (1, 0.1)),
#  ('021208', (1, 0.1)),
#  ('021217', (1, 0.1)),
#  ('021222', (1, 0.1)),
#  ('021224', (1, 0.1)),
#  ('021226', (1, 0.1)),
#  ('021231', (1, 0.1)),
#  ('021234', (1, 0.1)),
#  ('021255', (1, 0.1)),
#  ('021262', (1, 0.1)),
#  ('021273', (1, 0.1)),
#  ('021275', (1, 0.1)),
#  ('021277', (1, 0.1)),
#  ('021282', (1, 0.1)),
#  ('021288', (1, 0.1)),
#  ('021293', (1, 0.1)),
#  ('021299', (1, 0.1)),
#  ('021302', (1, 0.1)),
#  ('021311', (1, 0.1)),
#  ('021315', (1, 0.1)),
#  ('021316', (1, 0.1)),
#  ('021320', (1, 0.1)),
#  ('021330', (1, 0.1)),
#  ('021334', (1, 0.1)),
#  ('021339', (1, 0.1)),
#  ('021347', (1, 0.1)),
#  ('021359', (1, 0.1)),
#  ('021367', (1, 0.1)),
#  ('021387', (1, 0.1)),
#  ('021393', (1, 0.1)),
#  ('021406', (1, 0.1)),
#  ('021421', (1, 0.1)),
#  ('021431', (1, 0.1)),
#  ('021441', (1, 0.1)),
#  ('021448', (1, 0.1)),
#  ('021453', (1, 0.1)),
#  ('021454', (1, 0.1)),
#  ('021469', (1, 0.1)),
#  ('021483', (1, 0.1)),
#  ('021487', (1, 0.1)),
#  ('021498', (1, 0.1)),
#  ('021502', (1, 0.1)),
#  ('021507', (1, 0.1)),
#  ('021508', (1, 0.1)),
#  ('021510', (1, 0.1)),
#  ('021512', (1, 0.1)),
#  ('021516', (1, 0.1)),
#  ('021517', (1, 0.1)),
#  ('021550', (1, 0.1)),
#  ('021564', (1, 0.1)),
#  ('021570', (1, 0.1)),
#  ('021571', (1, 0.1)),
#  ('021581', (1, 0.1)),
#  ('021587', (1, 0.1)),
#  ('021614', (1, 0.1)),
#  ('021628', (1, 0.1)),
#  ('021633', (1, 0.1)),
#  ('021641', (1, 0.1)),
#  ('021645', (1, 0.1)),
#  ('021655', (1, 0.1)),
#  ('021670', (1, 0.1)),
#  ('021671', (1, 0.1)),
#  ('021675', (1, 0.1)),
#  ('021677', (1, 0.1)),
#  ('021686', (1, 0.1)),
#  ('021694', (1, 0.1)),
#  ('021710', (1, 0.1)),
#  ('021727', (1, 0.1)),
#  ('021747', (1, 0.1)),
#  ('021748', (1, 0.1)),
#  ('021756', (1, 0.1)),
#  ('021772', (1, 0.1)),
#  ('021773', (1, 0.1)),
#  ('021777', (1, 0.1)),
#  ('021778', (1, 0.1)),
#  ('021794', (1, 0.1)),
#  ('021807', (1, 0.1)),
#  ('021811', (1, 0.1)),
#  ('021812', (1, 0.1)),
#  ('021814', (1, 0.1)),
#  ('021817', (1, 0.1)),
#  ('021824', (1, 0.1)),
#  ('021832', (1, 0.1)),
#  ('021834', (1, 0.1)),
#  ('021846', (1, 0.1)),
#  ('021848', (1, 0.1)),
#  ('021851', (1, 0.1)),
#  ('021870', (1, 0.1)),
#  ('021874', (1, 0.1)),
#  ('021880', (1, 0.1)),
#  ('021891', (1, 0.1)),
#  ('021893', (1, 0.1)),
#  ('021900', (1, 0.1)),
#  ('021906', (1, 0.1)),
#  ('021911', (1, 0.1)),
#  ('021917', (1, 0.1)),
#  ('021919', (1, 0.1)),
#  ('021934', (1, 0.1)),
#  ('021936', (1, 0.1)),
#  ...]

# %%
# Nombre de document pertinent en fonction du nombre de terme de la requete
tmp = {k: (len(topics[k]), len({kd: s for kd, s in t if s > 0.9}))
       for k, t in query2relevance.items()}
tmp = [(a, b) for a, b in tmp.values()]
plt.scatter([e[0] for e in tmp], [e[1] for e in tmp])
plt.show()

# %%
import seaborn as sns

# %%
import numpy as np
# En fonction du seuil quel est le nombre de requetes qui retourne au moins 1 document ?
tmp = [(seuil, sum([sum(s > seuil for k_d, s in t if k_d != k) > 0 for k, t in query2relevance.items()]))
       for seuil in np.arange(0, 1, 0.1)]
plt.scatter(x=[e[0] for e in tmp], y=[e[1] for e in tmp])
plt.show()

# %%
# En fonction du seuil combien de document lié a au moins 1 requetes
tmp = []
for seuil in np.arange(0., 1, 0.1):
    doc_freq = Counter()
    for k_q, t in query2relevance.items():
        # Docs ok avec la requete k_q
        doc_freq.update([k for k, s in t if s > seuil and k != k_q])
    tmp.append((seuil, len(doc_freq)))
plt.scatter([e[0] for e in tmp], [e[1] for e in tmp])
plt.show()

# %%
Choisir les requêtes:
    - je veux des requêtes qui retournent plusieurs documents (sans compter le document original)
    -

# %%
# En fonction du seuil combien de requetes retournent n documents
tmp = [(seuil, [sum(s > seuil for k_d, s in t if k_d != k) for k, t in query2relevance.items()])
       for seuil in np.arange(0.5, 1, 0.1)]

# %%
df = pd.DataFrame((s, n) for s, l in tmp for n in l)

# %%
df[1][df[1]> 0].describe()
# Out:
# count    34658.000000
# mean        46.359311
# std        445.708952
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%         13.000000
# max      19999.000000
# Name: 1, dtype: float64

# %%
sns.violinplot(data=df[df[1]<20], x=0, y=1)
# Out:
# <AxesSubplot:xlabel='0', ylabel='1'>

# %%
df.loc[5]
# Out:
# 0    0.5
# 1    1.0
# Name: 5, dtype: float64

# %%
bins = [-1, 0, 1, 2, 3, 5, 10, 100, 20000]
df[2] = pd.cut(df[1], bins)
tmp = df[df[1]>0].groupby([0, 2]).count().unstack()

# %%
tmp.index = [round(x, 2) for x in tmp.index]

# %%
for l in tmp.iterrows():
    x = sns.lineplot(x=range(8), y=l[1][1], label=l[0])
x.set_xlabel(bins[2:])
# Out:
# Text(0.5, 0, '[1, 2, 3, 5, 10, 100, 20000]')

# %% [markdown]
# Je choisis un seuil de 0.7, car la courbe est bien baissée mais on a still pas mal de requetes a plus de 1000 doc.

# %% [markdown]
# Il faut enlever les requetes qui retrounenent beaucoup trop de document.

# %%
seuil = 0.7

# %%
tmp = {k: {k_d: s for k_d, s in t if s > 0.7} for k, t in query2relevance.items()}

# %%
[(k, topics[k]) for k, t in query2relevance.items() if len(t) > 1000]
# Out:
# [('020007', ['Methods', 'data', 'quality']),
#  ('020679', ['Fibonacci', 'r', 'r']),
#  ('020736', ['Systems', 'systems', 'systems', 'education', 'engineers']),
#  ('020776', ['mean']),
#  ('021211', ['Exact', 'value', 'ex(n;{C3,,Cs', 'x', '(', 'n', 'C', 'n', '(']),
#  ('021697', ['Performance']),
#  ('021741', ['Two', 'effective', 'measures']),
#  ('022295', ['Online', 'matching', 'line']),
#  ('022319', ['time', 'second', 'search']),
#  ('022414', ['Time']),
#  ('022737', ['service']),
#  ('022744', ['ring', 'grooming', 'problem']),
#  ('022919', ['stem', 'cell', 'research']),
#  ('023365', ['information', 'acquisition', 'information', 'age']),
#  ('023646', ['end', 'service', 'applications']),
#  ('023692', ['context']),
#  ('024036', ['DEA']),
#  ('024408', ['end', 'mobile', 'applications']),
#  ('024706', ['DEA']),
#  ('024921', ['method', 'Web', 'applications']),
#  ('024936', ['GERT', 'analysis', 'k', 'n']),
#  ('025129', ['pH', 'precipitation', 'process']),
#  ('025210', ['end']),
#  ('025228', ['filter', 'ad', 'quality']),
#  ('025295', ['New', 'results', 'convergence', "Adomian's", 'method']),
#  ('025490', ['One', 'line', 'points']),
#  ('025717', ['optimal', 'design', 'collaborative', 'design', 'network']),
#  ('025803', ['Information']),
#  ('025938', ['end']),
#  ('026051', ['complexity']),
#  ('026610', ['Experimental', 'program', 'analysis']),
#  ('027446', ['Lightning', 'search', 'algorithm']),
#  ('027557', ['location']),
#  ('027844', ['end', 'communication', 'networks']),
#  ('028097', ['System', 'Systems', 'Collaborative', 'Formation']),
#  ('028213', ['R']),
#  ('028276', ['query', 'ir', 'evaluation']),
#  ('028490', ['Development']),
#  ('028552', ['users']),
#  ('028633', ['complexity']),
#  ('029088', ['edge']),
#  ('029123', ['line', 'VQ', 'time']),
#  ('029864', ['Performance', 'analysis', 'requirements']),
#  ('029949', ['general', 'purpose', 'data', 'base', 'design']),
#  ('030618', ['text']),
#  ('030867', ['logical', 'approach', 'problems']),
#  ('030957', ['time']),
#  ('031400', ['association', 'analysis', 'approach']),
#  ('031431', ['Cell', 'formation', 'algorithm']),
#  ('031980', ['test', 'data', 'SOFL']),
#  ('032023', ['New', 'Model', 'Graph', 'Matching', 'Algorithm']),
#  ('032519', ['line']),
#  ('032811', ['Linear', 'Nonlinear', 'PCA', 'Linear', 'Programming']),
#  ('032853', ['lot-type', 'design', 'problem']),
#  ('033688',
#   ['nonlinear',
#    'difference',
#    'equation',
#    'system',
#    '=',
#    'n',
#    '/',
#    'x',
#    'n',
#    '=',
#    'x',
#    'n',
#    '/',
#    'n']),
#  ('034648', ['Optimal', 'workload', 'n']),
#  ('034858', ['understanding', 'information', 'systems']),
#  ('034909', ['order', 'order']),
#  ('034930', ['Solution', 'covering', 'problem']),
#  ('035054', ['health', 'information', 'systems']),
#  ('035230', ['animat', 'models', 'model']),
#  ('035691', ['End']),
#  ('035731', ['approach', 'test', 'cases', 'use', 'cases']),
#  ('035856', ['computer', 'literacy', 'computer']),
#  ('036593', ['line', 'application', 'scheduling']),
#  ('036594', ['data', 'warehouse', 'design']),
#  ('036892', ['model', 'self-organizing', 'systems']),
#  ('037252', ['optimal', 'v']),
#  ('037472', ['modeling']),
#  ('037601', ['Analysis']),
#  ('037969', ['search', 'system', 'work', 'task', 'completion']),
#  ('037978', ['n']),
#  ('038197', ['Fuzzy', 'Krasner', '(m', '(', ',', 'n', ')', '-hyperrings']),
#  ('038480', ['computation', 'mode']),
#  ('038601', ['place']),
#  ('038637', ['control']),
#  ('038813', ['model', 'implicit-invocation', 'systems']),
#  ('039026', ['Weiszfelds', 'Method', 'Old', 'New', 'Results']),
#  ('039333', ['method', 'information', 'database', 'design', 'process']),
#  ('039549', ['ad', 'hoc', 'networks'])]

# %% [markdown]
# ## Etude du TF max des termes
#
# En fait les termes les plus fréquents n'apparraissent que pour 5% max des requetes donc c'est ok pas de filtrage.

# %%
from collections import Counter
# Est-ce que le DF peut être superieur à 1 ?
tmp = {t_id: {w: df for w, df in Counter(t).items() if df > 4} for t_id, t in topics.items()}
{k: v for k, v in tmp.items() if v}
# Out:
# {'021118': {'center': 6, 'dot': 5}}

# %%
voc = {}
for v in topics.values():
    for t in set(map(str.lower, v)): # set car il peut y avoir plusieurs fois le même terme dans une requete
        if t not in voc:
            voc[t] = 0
        voc[t] += 1

# %%
sorted([(t, f, f / len(topics)*100) for t, f in voc.items()], key=lambda x: x[1], reverse=True)
# Out:
# [('analysis', 1149, 5.745),
#  ('networks', 1041, 5.205),
#  ('systems', 997, 4.984999999999999),
#  ('model', 965, 4.825),
#  ('system', 806, 4.03),
#  ('data', 753, 3.765),
#  ('approach', 728, 3.64),
#  ('design', 706, 3.53),
#  ('method', 702, 3.51),
#  ('algorithm', 695, 3.4750000000000005),
#  ('control', 530, 2.65),
#  ('information', 516, 2.58),
#  ('network', 505, 2.5250000000000004),
#  ('optimization', 457, 2.2849999999999997),
#  ('models', 456, 2.2800000000000002),
#  ('fuzzy', 453, 2.265),
#  ('dynamic', 402, 2.01),
#  ('new', 402, 2.01),
#  ('application', 401, 2.005),
#  ('performance', 400, 2.0),
#  ('problem', 389, 1.9449999999999998),
#  ('wireless', 382, 1.91),
#  ('image', 376, 1.8800000000000001),
#  ('detection', 373, 1.865),
#  ('applications', 366, 1.83),
#  ('algorithms', 354, 1.77),
#  ('efficient', 347, 1.735),
#  ('study', 340, 1.7000000000000002),
#  ('problems', 337, 1.685),
#  ('neural', 323, 1.6150000000000002),
#  ('evaluation', 320, 1.6),
#  ('simulation', 316, 1.58),
#  ('adaptive', 313, 1.5650000000000002),
#  ('management', 310, 1.55),
#  ('estimation', 309, 1.545),
#  ('mobile', 281, 1.405),
#  ('framework', 280, 1.4000000000000001),
#  ('web', 275, 1.375),
#  ('learning', 274, 1.37),
#  ('distributed', 271, 1.355),
#  ('software', 268, 1.34),
#  ('development', 262, 1.31),
#  ('multiple', 261, 1.3050000000000002),
#  ('methods', 260, 1.3),
#  ('classification', 260, 1.3),
#  ('modeling', 255, 1.275),
#  ('sensor', 252, 1.26),
#  ('power', 249, 1.2449999999999999),
#  ('scheme', 247, 1.2349999999999999),
#  ('recognition', 246, 1.23),
#  ('based', 244, 1.22),
#  ('time', 240, 1.2),
#  ('selection', 238, 1.1900000000000002),
#  ('hybrid', 234, 1.17),
#  ('optimal', 234, 1.17),
#  ('search', 233, 1.165),
#  ('programming', 232, 1.16),
#  ('support', 231, 1.155),
#  ('scheduling', 227, 1.135),
#  ('process', 221, 1.105),
#  ('linear', 220, 1.0999999999999999),
#  ('architecture', 220, 1.0999999999999999),
#  ('finite', 216, 1.08),
#  ('3d', 216, 1.08),
#  ('parallel', 214, 1.0699999999999998),
#  ('flow', 204, 1.02),
#  ('equations', 201, 1.005),
#  ('nonlinear', 200, 1.0),
#  ('video', 199, 0.9950000000000001),
#  ('robust', 195, 0.975),
#  ('genetic', 195, 0.975),
#  ('functions', 185, 0.9249999999999999),
#  ('decision', 184, 0.9199999999999999),
#  ('generation', 183, 0.915),
#  ('element', 181, 0.905),
#  ('images', 179, 0.895),
#  ('novel', 179, 0.895),
#  ('fast', 176, 0.88),
#  ('techniques', 174, 0.8699999999999999),
#  ('implementation', 174, 0.8699999999999999),
#  ('numerical', 173, 0.865),
#  ('virtual', 172, 0.86),
#  ('communication', 171, 0.855),
#  ('social', 171, 0.855),
#  ('prediction', 170, 0.8500000000000001),
#  ('energy', 170, 0.8500000000000001),
#  ('local', 169, 0.845),
#  ('automatic', 164, 0.8200000000000001),
#  ('graphs', 163, 0.815),
#  ('use', 162, 0.8099999999999999),
#  ('knowledge', 160, 0.8),
#  ('generalized', 160, 0.8),
#  ('digital', 159, 0.795),
#  ('case', 159, 0.795),
#  ('human', 159, 0.795),
#  ('distribution', 159, 0.795),
#  ('service', 159, 0.795),
#  ('comparison', 155, 0.775),
#  ('theory', 155, 0.775),
#  ('environment', 154, 0.77),
#  ('identification', 153, 0.765),
#  ('real-time', 152, 0.76),
#  ('effects', 151, 0.755),
#  ('high', 150, 0.75),
#  ('processing', 150, 0.75),
#  ('structure', 149, 0.745),
#  ('retrieval', 148, 0.74),
#  ('computer', 147, 0.735),
#  ('quality', 147, 0.735),
#  ('structures', 146, 0.73),
#  ('technique', 145, 0.7250000000000001),
#  ('complex', 145, 0.7250000000000001),
#  ('segmentation', 145, 0.7250000000000001),
#  ('solution', 144, 0.72),
#  ('random', 144, 0.72),
#  ('large', 140, 0.7000000000000001),
#  ('stochastic', 138, 0.69),
#  ('research', 138, 0.69),
#  ('visual', 137, 0.685),
#  ('improved', 136, 0.6799999999999999),
#  ('computing', 135, 0.675),
#  ('interaction', 135, 0.675),
#  ('feature', 135, 0.675),
#  ('impact', 134, 0.67),
#  ('online', 134, 0.67),
#  ('machine', 134, 0.67),
#  ('differential', 134, 0.67),
#  ('motion', 133, 0.6649999999999999),
#  ('boundary', 132, 0.66),
#  ('effect', 132, 0.66),
#  ('vector', 131, 0.655),
#  ('complexity', 130, 0.65),
#  ('approximation', 130, 0.65),
#  ('computation', 129, 0.645),
#  ('function', 129, 0.645),
#  ('tool', 128, 0.64),
#  ('dynamics', 127, 0.635),
#  ('properties', 127, 0.635),
#  ('user', 127, 0.635),
#  ('stability', 126, 0.63),
#  ('space', 126, 0.63),
#  ('sets', 126, 0.63),
#  ('integrated', 124, 0.62),
#  ('technology', 123, 0.615),
#  ('tracking', 123, 0.615),
#  ('global', 122, 0.61),
#  ('environments', 122, 0.61),
#  ('interactive', 122, 0.61),
#  ('protocol', 122, 0.61),
#  ('two', 122, 0.61),
#  ('services', 121, 0.605),
#  ('evolution', 121, 0.605),
#  ('computational', 120, 0.6),
#  ('integration', 119, 0.5950000000000001),
#  ('access', 119, 0.5950000000000001),
#  ('surface', 119, 0.5950000000000001),
#  ('logic', 119, 0.5950000000000001),
#  ('spatial', 118, 0.59),
#  ('memory', 118, 0.59),
#  ('traffic', 117, 0.585),
#  ('codes', 117, 0.585),
#  ('modelling', 114, 0.5700000000000001),
#  ('test', 113, 0.565),
#  (':', 112, 0.5599999999999999),
#  ('mining', 112, 0.5599999999999999),
#  ('planning', 111, 0.555),
#  ('routing', 111, 0.555),
#  ('statistical', 111, 0.555),
#  ('engineering', 111, 0.555),
#  ('assessment', 110, 0.5499999999999999),
#  ('heterogeneous', 109, 0.545),
#  ('reconstruction', 109, 0.545),
#  ('discrete', 108, 0.54),
#  ('program', 108, 0.54),
#  ('evolutionary', 108, 0.54),
#  ('extraction', 108, 0.54),
#  ('representation', 107, 0.5349999999999999),
#  ('hierarchical', 107, 0.5349999999999999),
#  ('matrix', 107, 0.5349999999999999),
#  ('synthesis', 106, 0.53),
#  ('ad', 105, 0.525),
#  ('optical', 105, 0.525),
#  ('processes', 104, 0.52),
#  ('solutions', 104, 0.52),
#  ('pattern', 104, 0.52),
#  ('domain', 104, 0.52),
#  ('field', 104, 0.52),
#  ('set', 104, 0.52),
#  ('tree', 103, 0.515),
#  ('reduction', 103, 0.515),
#  ('behavior', 103, 0.515),
#  ('bayesian', 103, 0.515),
#  ('graph', 102, 0.51),
#  ('order', 102, 0.51),
#  ('state', 102, 0.51),
#  ('quantum', 100, 0.5),
#  ('-', 100, 0.5),
#  ('general', 100, 0.5),
#  ('error', 100, 0.5),
#  ('equation', 100, 0.5),
#  ('strategies', 99, 0.49500000000000005),
#  ('security', 99, 0.49500000000000005),
#  ('artificial', 99, 0.49500000000000005),
#  ('machines', 98, 0.49),
#  ('structural', 98, 0.49),
#  ('intelligent', 98, 0.49),
#  ('patterns', 98, 0.49),
#  ('automated', 97, 0.485),
#  ('hoc', 97, 0.485),
#  ('allocation', 97, 0.485),
#  ('media', 97, 0.485),
#  ('verification', 97, 0.485),
#  ('object', 97, 0.485),
#  ('regression', 97, 0.485),
#  ('semantic', 96, 0.48),
#  ('methodology', 95, 0.475),
#  ('resource', 95, 0.475),
#  ('number', 95, 0.475),
#  ('testing', 93, 0.46499999999999997),
#  ('language', 93, 0.46499999999999997),
#  ('particle', 92, 0.45999999999999996),
#  ('constraints', 91, 0.455),
#  ('rate', 91, 0.455),
#  ('shape', 91, 0.455),
#  ('channel', 91, 0.455),
#  ('point', 90, 0.44999999999999996),
#  ('class', 90, 0.44999999999999996),
#  ('grid', 90, 0.44999999999999996),
#  ('collaborative', 90, 0.44999999999999996),
#  ('code', 90, 0.44999999999999996),
#  ('interface', 90, 0.44999999999999996),
#  ('clustering', 89, 0.445),
#  ('simulations', 89, 0.445),
#  ('content', 88, 0.44),
#  ('empirical', 88, 0.44),
#  ('speech', 88, 0.44),
#  ('signal', 88, 0.44),
#  ('low', 88, 0.44),
#  ('parameters', 87, 0.43499999999999994),
#  ('matching', 87, 0.43499999999999994),
#  ('compression', 87, 0.43499999999999994),
#  ('cognitive', 86, 0.43),
#  ('product', 86, 0.43),
#  ('internet', 85, 0.42500000000000004),
#  ('monitoring', 85, 0.42500000000000004),
#  ('features', 85, 0.42500000000000004),
#  ('robot', 85, 0.42500000000000004),
#  ('programs', 85, 0.42500000000000004),
#  ('functional', 84, 0.42),
#  ('continuous', 84, 0.42),
#  ('construction', 84, 0.42),
#  ('decomposition', 84, 0.42),
#  ('distance', 84, 0.42),
#  ('partial', 84, 0.42),
#  ('maximum', 84, 0.42),
#  ('characterization', 84, 0.42),
#  ('variable', 83, 0.415),
#  ('electronic', 83, 0.415),
#  ('fault', 82, 0.41000000000000003),
#  ('multimedia', 82, 0.41000000000000003),
#  ('probabilistic', 82, 0.41000000000000003),
#  ('efficiency', 82, 0.41000000000000003),
#  ('location', 82, 0.41000000000000003),
#  ('strategy', 82, 0.41000000000000003),
#  ('group', 81, 0.40499999999999997),
#  ('circuits', 81, 0.40499999999999997),
#  ('objects', 81, 0.40499999999999997),
#  ('simple', 81, 0.40499999999999997),
#  ('feedback', 80, 0.4),
#  ('path', 80, 0.4),
#  ('line', 80, 0.4),
#  ('visualization', 80, 0.4),
#  ('activity', 79, 0.395),
#  ('role', 79, 0.395),
#  ('effective', 79, 0.395),
#  ('capacity', 78, 0.38999999999999996),
#  ('health', 78, 0.38999999999999996),
#  ('single', 78, 0.38999999999999996),
#  ('large-scale', 77, 0.385),
#  ('noise', 77, 0.385),
#  ('cell', 77, 0.385),
#  ('reliability', 77, 0.385),
#  ('polynomial', 77, 0.385),
#  ('type', 77, 0.385),
#  ('filter', 77, 0.385),
#  ('series', 77, 0.385),
#  ('trees', 76, 0.38),
#  ('cellular', 76, 0.38),
#  ('joint', 76, 0.38),
#  ('uncertainty', 76, 0.38),
#  ('response', 76, 0.38),
#  ('sequences', 76, 0.38),
#  ('active', 75, 0.375),
#  ('protocols', 75, 0.375),
#  ('agents', 74, 0.37),
#  ('parameter', 74, 0.37),
#  ('mesh', 74, 0.37),
#  ('medical', 74, 0.37),
#  ('experimental', 74, 0.37),
#  ('transfer', 73, 0.365),
#  ('embedded', 73, 0.365),
#  ('delay', 73, 0.365),
#  ('spaces', 73, 0.365),
#  ('context', 73, 0.365),
#  ('level', 73, 0.365),
#  ('mapping', 72, 0.36),
#  ('tools', 72, 0.36),
#  ('geometric', 72, 0.36),
#  ('fusion', 72, 0.36),
#  ('frequency', 72, 0.36),
#  ('source', 72, 0.36),
#  ('cost', 72, 0.36),
#  ('value', 71, 0.35500000000000004),
#  ('database', 71, 0.35500000000000004),
#  ('three-dimensional', 71, 0.35500000000000004),
#  ('query', 71, 0.35500000000000004),
#  ('chain', 70, 0.35000000000000003),
#  ('transform', 70, 0.35000000000000003),
#  ('bounds', 70, 0.35000000000000003),
#  ('supply', 70, 0.35000000000000003),
#  ('comparative', 69, 0.345),
#  ('diagnosis', 69, 0.345),
#  ('wavelet', 69, 0.345),
#  ('review', 69, 0.345),
#  ('production', 69, 0.345),
#  ('load', 69, 0.345),
#  ('schemes', 69, 0.345),
#  ('flexible', 68, 0.33999999999999997),
#  ('investigation', 68, 0.33999999999999997),
#  ('text', 68, 0.33999999999999997),
#  ('conditions', 68, 0.33999999999999997),
#  ('characteristics', 68, 0.33999999999999997),
#  ('task', 67, 0.335),
#  ('devices', 67, 0.335),
#  ('sparse', 67, 0.335),
#  ('multi-objective', 67, 0.335),
#  ('adaptation', 67, 0.335),
#  ('color', 67, 0.335),
#  ('topology', 66, 0.33),
#  ('temporal', 66, 0.33),
#  ('studies', 65, 0.325),
#  ('cooperative', 65, 0.325),
#  ('channels', 65, 0.325),
#  ('risk', 64, 0.32),
#  ('two-dimensional', 64, 0.32),
#  ('markov', 64, 0.32),
#  ('mixed', 64, 0.32),
#  ('assignment', 64, 0.32),
#  ('event', 63, 0.315),
#  ('swarm', 63, 0.315),
#  ('molecular', 63, 0.315),
#  ('spectral', 63, 0.315),
#  ('key', 63, 0.315),
#  ('databases', 63, 0.315),
#  ('practical', 63, 0.315),
#  ('real', 63, 0.315),
#  ('measurement', 63, 0.315),
#  ('clinical', 63, 0.315),
#  ('constraint', 63, 0.315),
#  ('density', 63, 0.315),
#  ('diffusion', 62, 0.31),
#  ('game', 62, 0.31),
#  ('phase', 62, 0.31),
#  ('influence', 62, 0.31),
#  ('manufacturing', 62, 0.31),
#  ('transmission', 62, 0.31),
#  ('mechanism', 61, 0.305),
#  ('natural', 61, 0.305),
#  ('different', 61, 0.305),
#  ('component', 61, 0.305),
#  ('queries', 61, 0.305),
#  ('automata', 61, 0.305),
#  ('similarity', 61, 0.305),
#  ('inference', 61, 0.305),
#  ('theoretical', 61, 0.305),
#  ('measures', 61, 0.305),
#  ('rules', 61, 0.305),
#  ('surfaces', 61, 0.305),
#  ('weighted', 60, 0.3),
#  ('binary', 60, 0.3),
#  ('transformation', 60, 0.3),
#  ('face', 60, 0.3),
#  ('minimum', 60, 0.3),
#  ('games', 60, 0.3),
#  ('survey', 60, 0.3),
#  ('business', 60, 0.3),
#  ('small', 59, 0.295),
#  ('scalable', 59, 0.295),
#  ('flows', 59, 0.295),
#  ('water', 59, 0.295),
#  ('accurate', 59, 0.295),
#  ('controller', 59, 0.295),
#  ('open', 58, 0.29),
#  ('perspective', 58, 0.29),
#  ('cancer', 58, 0.29),
#  ('authentication', 57, 0.28500000000000003),
#  ('enhanced', 57, 0.28500000000000003),
#  ('interactions', 57, 0.28500000000000003),
#  ('part', 57, 0.28500000000000003),
#  ('formal', 57, 0.28500000000000003),
#  ('map', 57, 0.28500000000000003),
#  ('iterative', 57, 0.28500000000000003),
#  ('science', 56, 0.27999999999999997),
#  ('cloud', 56, 0.27999999999999997),
#  ('coding', 56, 0.27999999999999997),
#  ('mode', 56, 0.27999999999999997),
#  ('kernel', 56, 0.27999999999999997),
#  ('interval', 56, 0.27999999999999997),
#  ('failure', 56, 0.27999999999999997),
#  ('protein', 56, 0.27999999999999997),
#  ('results', 56, 0.27999999999999997),
#  ('smart', 56, 0.27999999999999997),
#  ('formulation', 55, 0.27499999999999997),
#  ('synchronization', 55, 0.27499999999999997),
#  ('approaches', 55, 0.27499999999999997),
#  ('discovery', 55, 0.27499999999999997),
#  ('action', 55, 0.27499999999999997),
#  ('cells', 54, 0.27),
#  ('reliable', 54, 0.27),
#  ('static', 54, 0.27),
#  ('direct', 54, 0.27),
#  ('java', 54, 0.27),
#  ('constrained', 54, 0.27),
#  ('navigation', 54, 0.27),
#  ('requirements', 54, 0.27),
#  ('basis', 54, 0.27),
#  ('fields', 54, 0.27),
#  ('resolution', 54, 0.27),
#  ('signals', 54, 0.27),
#  ('fluid', 53, 0.265),
#  ('magnetic', 53, 0.265),
#  ('thermal', 53, 0.265),
#  ('rough', 53, 0.265),
#  ('chip', 53, 0.265),
#  ('curves', 53, 0.265),
#  ('sensing', 53, 0.265),
#  ('volume', 52, 0.26),
#  ('layer', 52, 0.26),
#  ('concept', 52, 0.26),
#  ('sequence', 52, 0.26),
#  ('factors', 52, 0.26),
#  ('vehicle', 52, 0.26),
#  ('mechanisms', 52, 0.26),
#  ('issues', 52, 0.26),
#  ('modified', 52, 0.26),
#  ('grids', 52, 0.26),
#  ('hardware', 52, 0.26),
#  ('convergence', 52, 0.26),
#  ('size', 52, 0.26),
#  ('policy', 52, 0.26),
#  ('parametric', 52, 0.26),
#  ('semantics', 51, 0.255),
#  ('protection', 51, 0.255),
#  ('points', 51, 0.255),
#  ('block', 51, 0.255),
#  ('imaging', 51, 0.255),
#  ('secure', 51, 0.255),
#  ('training', 51, 0.255),
#  ('classifiers', 51, 0.255),
#  ('radio', 51, 0.255),
#  ('xml', 51, 0.255),
#  ('current', 51, 0.255),
#  ('sampling', 51, 0.255),
#  ('sharing', 50, 0.25),
#  ('wave', 50, 0.25),
#  ('index', 50, 0.25),
#  ('procedure', 50, 0.25),
#  ('agent', 50, 0.25),
#  ('architectures', 50, 0.25),
#  ('operators', 49, 0.245),
#  ('vision', 49, 0.245),
#  ('simultaneous', 49, 0.245),
#  ('scientific', 49, 0.245),
#  ('potential', 49, 0.245),
#  ('education', 49, 0.245),
#  ('combined', 49, 0.245),
#  ('localization', 49, 0.245),
#  ('project', 49, 0.245),
#  ('propagation', 48, 0.24),
#  ('difference', 48, 0.24),
#  ('platform', 48, 0.24),
#  ('fractional', 48, 0.24),
#  ('document', 48, 0.24),
#  ('spectrum', 48, 0.24),
#  ('gene', 48, 0.24),
#  ('validation', 48, 0.24),
#  ('critical', 48, 0.24),
#  ('technologies', 47, 0.23500000000000001),
#  ('multi-agent', 47, 0.23500000000000001),
#  ('gaussian', 47, 0.23500000000000001),
#  ('relationship', 47, 0.23500000000000001),
#  ('cluster', 47, 0.23500000000000001),
#  ('area', 47, 0.23500000000000001),
#  ('elements', 47, 0.23500000000000001),
#  ('scale', 47, 0.23500000000000001),
#  ('reasoning', 47, 0.23500000000000001),
#  ('enhancement', 47, 0.23500000000000001),
#  ('interpolation', 47, 0.23500000000000001),
#  ('sensitivity', 47, 0.23500000000000001),
#  ('carlo', 47, 0.23500000000000001),
#  ('exploration', 46, 0.22999999999999998),
#  ('market', 46, 0.22999999999999998),
#  ('texture', 46, 0.22999999999999998),
#  ('transport', 46, 0.22999999999999998),
#  ('students', 46, 0.22999999999999998),
#  ('behaviour', 46, 0.22999999999999998),
#  ('uncertain', 46, 0.22999999999999998),
#  ('soft', 46, 0.22999999999999998),
#  ('privacy', 46, 0.22999999999999998),
#  ('advanced', 46, 0.22999999999999998),
#  ('exact', 46, 0.22999999999999998),
#  ('exponential', 46, 0.22999999999999998),
#  ('expression', 46, 0.22999999999999998),
#  ('probability', 46, 0.22999999999999998),
#  ('operations', 45, 0.22499999999999998),
#  ('interfaces', 45, 0.22499999999999998),
#  ('three', 45, 0.22499999999999998),
#  ('measure', 45, 0.22499999999999998),
#  ('filtering', 45, 0.22499999999999998),
#  ('chemical', 45, 0.22499999999999998),
#  ('multivariate', 45, 0.22499999999999998),
#  ('correlation', 45, 0.22499999999999998),
#  ('meshes', 45, 0.22499999999999998),
#  ('processors', 45, 0.22499999999999998),
#  ('web-based', 45, 0.22499999999999998),
#  ('minimization', 45, 0.22499999999999998),
#  ('relational', 45, 0.22499999999999998),
#  ('switching', 45, 0.22499999999999998),
#  ('maps', 45, 0.22499999999999998),
#  ('input', 45, 0.22499999999999998),
#  ('monte', 45, 0.22499999999999998),
#  ('brain', 45, 0.22499999999999998),
#  ('total', 44, 0.22),
#  ('region', 44, 0.22),
#  ('incremental', 44, 0.22),
#  ('analytical', 44, 0.22),
#  ('challenges', 44, 0.22),
#  ('recovery', 44, 0.22),
#  ('documents', 44, 0.22),
#  ('improvement', 44, 0.22),
#  ('convex', 44, 0.22),
#  ('presence', 44, 0.22),
#  ('aggregation', 43, 0.215),
#  ('distributions', 43, 0.215),
#  ('periodic', 43, 0.215),
#  ('object-oriented', 43, 0.215),
#  ('time-varying', 43, 0.215),
#  ('times', 43, 0.215),
#  ('qos', 43, 0.215),
#  ('elastic', 42, 0.21),
#  ('circuit', 42, 0.21),
#  ('packet', 42, 0.21),
#  ('classifier', 42, 0.21),
#  ('languages', 42, 0.21),
#  ('types', 42, 0.21),
#  ('description', 42, 0.21),
#  ('heuristic', 42, 0.21),
#  ('coupled', 42, 0.21),
#  ('metric', 42, 0.21),
#  ('peer', 42, 0.21),
#  ('measurements', 42, 0.21),
#  ('specification', 42, 0.21),
#  ('delays', 42, 0.21),
#  ('designs', 42, 0.21),
#  ('mixture', 42, 0.21),
#  ('metrics', 42, 0.21),
#  ('geometry', 41, 0.20500000000000002),
#  ('expert', 41, 0.20500000000000002),
#  ('registration', 41, 0.20500000000000002),
#  ('cmos', 41, 0.20500000000000002),
#  ('common', 41, 0.20500000000000002),
#  ('implications', 41, 0.20500000000000002),
#  ('components', 41, 0.20500000000000002),
#  ('representations', 41, 0.20500000000000002),
#  ('lattice', 41, 0.20500000000000002),
#  ('independent', 41, 0.20500000000000002),
#  ('multidimensional', 41, 0.20500000000000002),
#  ('systematic', 41, 0.20500000000000002),
#  ('public', 41, 0.20500000000000002),
#  ('extension', 41, 0.20500000000000002),
#  ('mathematical', 40, 0.2),
#  ('dna', 40, 0.2),
#  ('free', 40, 0.2),
#  ('sequential', 40, 0.2),
#  ('storage', 40, 0.2),
#  ('extended', 40, 0.2),
#  ('urban', 40, 0.2),
#  ('deterministic', 40, 0.2),
#  ('uniform', 40, 0.2),
#  ('communications', 40, 0.2),
#  ('multimodal', 40, 0.2),
#  ('formation', 40, 0.2),
#  ('2d', 40, 0.2),
#  ('edge', 40, 0.2),
#  ('environmental', 40, 0.2),
#  ('alignment', 40, 0.2),
#  ('quantitative', 40, 0.2),
#  ('transition', 40, 0.2),
#  ('approximate', 40, 0.2),
#  ('multicast', 39, 0.19499999999999998),
#  ('collaboration', 39, 0.19499999999999998),
#  ('integral', 39, 0.19499999999999998),
#  ('mimo', 39, 0.19499999999999998),
#  ('filters', 39, 0.19499999999999998),
#  ('criteria', 39, 0.19499999999999998),
#  ('composition', 39, 0.19499999999999998),
#  ('materials', 39, 0.19499999999999998),
#  ('errors', 39, 0.19499999999999998),
#  ('experience', 39, 0.19499999999999998),
#  ('world', 39, 0.19499999999999998),
#  ('separation', 39, 0.19499999999999998),
#  ('placement', 39, 0.19499999999999998),
#  ('minimal', 39, 0.19499999999999998),
#  ('electrical', 38, 0.19),
#  ('demand', 38, 0.19),
#  ('unified', 38, 0.19),
#  ('trust', 38, 0.19),
#  ('induction', 38, 0.19),
#  ('assembly', 38, 0.19),
#  ('colony', 38, 0.19),
#  ('delivery', 38, 0.19),
#  ('remote', 38, 0.19),
#  ('stress', 38, 0.19),
#  ('speed', 38, 0.19),
#  ('orthogonal', 38, 0.19),
#  ('force', 38, 0.19),
#  ('predictive', 38, 0.19),
#  ('maintenance', 38, 0.19),
#  ('reality', 38, 0.19),
#  ('reconfigurable', 38, 0.19),
#  ('rule', 37, 0.185),
#  ('execution', 37, 0.185),
#  ('view', 37, 0.185),
#  ('inverse', 37, 0.185),
#  ('calculation', 37, 0.185),
#  ('decentralized', 37, 0.185),
#  ('topological', 37, 0.185),
#  ('composite', 37, 0.185),
#  ('sensors', 37, 0.185),
#  ('note', 37, 0.185),
#  ('structured', 37, 0.185),
#  ('domains', 36, 0.18),
#  ('autonomous', 36, 0.18),
#  ('community', 36, 0.18),
#  ('disease', 36, 0.18),
#  ('array', 36, 0.18),
#  ('tasks', 36, 0.18),
#  ('link', 36, 0.18),
#  ('unit', 36, 0.18),
#  ('resources', 36, 0.18),
#  ('voltage', 36, 0.18),
#  ('concurrent', 36, 0.18),
#  ('states', 36, 0.18),
#  ('mobility', 36, 0.18),
#  ('boolean', 36, 0.18),
#  ('treatment', 36, 0.18),
#  ('chaotic', 35, 0.17500000000000002),
#  ('dual', 35, 0.17500000000000002),
#  ('transformations', 35, 0.17500000000000002),
#  ('positive', 35, 0.17500000000000002),
#  ('future', 35, 0.17500000000000002),
#  ('controlled', 35, 0.17500000000000002),
#  ('sources', 35, 0.17500000000000002),
#  ('relations', 35, 0.17500000000000002),
#  ('interference', 35, 0.17500000000000002),
#  ('perception', 35, 0.17500000000000002),
#  ('tcp', 35, 0.17500000000000002),
#  ('beam', 35, 0.17500000000000002),
#  ('cache', 35, 0.17500000000000002),
#  ('elliptic', 35, 0.17500000000000002),
#  ('industrial', 35, 0.17500000000000002),
#  ('biological', 35, 0.17500000000000002),
#  ('care', 35, 0.17500000000000002),
#  ('3-d', 35, 0.17500000000000002),
#  ('groups', 35, 0.17500000000000002),
#  ('variational', 35, 0.17500000000000002),
#  ('factor', 35, 0.17500000000000002),
#  ('laser', 35, 0.17500000000000002),
#  ('condition', 35, 0.17500000000000002),
#  ('forecasting', 35, 0.17500000000000002),
#  ('exchange', 35, 0.17500000000000002),
#  ('planar', 35, 0.17500000000000002),
#  ('variables', 34, 0.16999999999999998),
#  ('bandwidth', 34, 0.16999999999999998),
#  ('evidence', 34, 0.16999999999999998),
#  ('understanding', 34, 0.16999999999999998),
#  ('users', 34, 0.16999999999999998),
#  ('temperature', 34, 0.16999999999999998),
#  ('diversity', 34, 0.16999999999999998),
#  ('integer', 34, 0.16999999999999998),
#  ('acoustic', 34, 0.16999999999999998),
#  ('fully', 34, 0.16999999999999998),
#  ('robots', 34, 0.16999999999999998),
#  ('change', 34, 0.16999999999999998),
#  ('indexing', 34, 0.16999999999999998),
#  ('multiobjective', 34, 0.16999999999999998),
#  ('robotic', 34, 0.16999999999999998),
#  ('numbers', 34, 0.16999999999999998),
#  ('industry', 34, 0.16999999999999998),
#  ('experiments', 34, 0.16999999999999998),
#  ('changes', 34, 0.16999999999999998),
#  ('generic', 34, 0.16999999999999998),
#  ('operator', 34, 0.16999999999999998),
#  ('output', 33, 0.165),
#  ('physical', 33, 0.165),
#  ('compact', 33, 0.165),
#  ('classes', 33, 0.165),
#  ('optimisation', 33, 0.165),
#  ('organizational', 33, 0.165),
#  ('highly', 33, 0.165),
#  ('determination', 33, 0.165),
#  ('collection', 33, 0.165),
#  ('conceptual', 33, 0.165),
#  ('paths', 33, 0.165),
#  ('accuracy', 33, 0.165),
#  ('ontology', 33, 0.165),
#  ('arrays', 33, 0.165),
#  ('heat', 33, 0.165),
#  ('family', 33, 0.165),
#  ('generator', 33, 0.165),
#  ('quadratic', 33, 0.165),
#  ('aspects', 32, 0.16),
#  ('matrices', 32, 0.16),
#  ('job', 32, 0.16),
#  ('theorem', 32, 0.16),
#  ('model-based', 32, 0.16),
#  ('streaming', 32, 0.16),
#  ('symmetric', 32, 0.16),
#  ('selective', 32, 0.16),
#  ('events', 32, 0.16),
#  ('concepts', 32, 0.16),
#  ('shop', 32, 0.16),
#  ('likelihood', 32, 0.16),
#  ('plane', 32, 0.16),
#  ('algebraic', 32, 0.16),
#  ('lines', 32, 0.16),
#  ('modulation', 32, 0.16),
#  ('tomography', 32, 0.16),
#  ('configuration', 32, 0.16),
#  ('coverage', 32, 0.16),
#  ('ubiquitous', 31, 0.155),
#  ('recommendation', 31, 0.155),
#  ('correction', 31, 0.155),
#  ('standard', 31, 0.155),
#  ('end', 31, 0.155),
#  ('reactive', 31, 0.155),
#  ('high-performance', 31, 0.155),
#  ('motor', 31, 0.155),
#  ('pressure', 31, 0.155),
#  ('means', 31, 0.155),
#  ('transportation', 31, 0.155),
#  ('clusters', 31, 0.155),
#  ('second', 31, 0.155),
#  ('rates', 31, 0.155),
#  ('association', 31, 0.155),
#  ('life', 31, 0.155),
#  ('recursive', 31, 0.155),
#  ('p2p', 31, 0.155),
#  ('economic', 31, 0.155),
#  ('double', 30, 0.15),
#  ('ip', 30, 0.15),
#  ('patients', 30, 0.15),
#  ('analog', 30, 0.15),
#  ('safety', 30, 0.15),
#  ('terms', 30, 0.15),
#  ('layout', 30, 0.15),
#  ('knowledge-based', 30, 0.15),
#  ('dynamical', 30, 0.15),
#  ('nets', 30, 0.15),
#  ('nodes', 30, 0.15),
#  ('educational', 30, 0.15),
#  ('non-linear', 30, 0.15),
#  ('length', 30, 0.15),
#  ('variation', 30, 0.15),
#  ('ii', 30, 0.15),
#  ('normal', 30, 0.15),
#  ('curve', 30, 0.15),
#  ('heart', 30, 0.15),
#  ('building', 30, 0.15),
#  ('second-order', 30, 0.15),
#  ('usability', 30, 0.15),
#  ('projection', 30, 0.15),
#  ('comprehensive', 30, 0.15),
#  ('coordination', 30, 0.15),
#  ('projects', 30, 0.15),
#  ('compensation', 30, 0.15),
#  ('mechanical', 30, 0.15),
#  ('reference', 30, 0.15),
#  ('simulated', 30, 0.15),
#  ('vibration', 30, 0.15),
#  ('financial', 30, 0.15),
#  ('transient', 30, 0.15),
#  ('arbitrary', 30, 0.15),
#  ('node', 29, 0.145),
#  ('implicit', 29, 0.145),
#  ('invariant', 29, 0.145),
#  ('broadcast', 29, 0.145),
#  ('modular', 29, 0.145),
#  ('mutual', 29, 0.145),
#  ('gradient', 29, 0.145),
#  ('recurrent', 29, 0.145),
#  ('views', 29, 0.145),
#  ('relevance', 29, 0.145),
#  ('operation', 29, 0.145),
#  ('recommender', 29, 0.145),
#  ('bounded', 29, 0.145),
#  ('universal', 29, 0.145),
#  ('competitive', 29, 0.145),
#  ('solver', 29, 0.145),
#  ('contact', 29, 0.145),
#  ('inventory', 29, 0.145),
#  ('statistics', 29, 0.145),
#  ('tolerance', 29, 0.145),
#  ('adoption', 29, 0.145),
#  ('fourier', 29, 0.145),
#  ('breast', 29, 0.145),
#  ('rational', 29, 0.145),
#  ('levels', 29, 0.145),
#  ('translation', 29, 0.145),
#  ('augmented', 29, 0.145),
#  ('camera', 29, 0.145),
#  ('symbolic', 29, 0.145),
#  ('relationships', 29, 0.145),
#  ('graphics', 29, 0.145),
#  ('ensemble', 29, 0.145),
#  ('discrete-time', 28, 0.13999999999999999),
#  ('loss', 28, 0.13999999999999999),
#  ('dimensional', 28, 0.13999999999999999),
#  ('lower', 28, 0.13999999999999999),
#  ('asymmetric', 28, 0.13999999999999999),
#  ('annotation', 28, 0.13999999999999999),
#  ('combinatorial', 28, 0.13999999999999999),
#  ('limited', 28, 0.13999999999999999),
#  ('first', 28, 0.13999999999999999),
#  ('consistency', 28, 0.13999999999999999),
#  ('rendering', 28, 0.13999999999999999),
#  ('gas', 28, 0.13999999999999999),
#  ('biomedical', 28, 0.13999999999999999),
#  ('interpretation', 28, 0.13999999999999999),
#  ('processor', 28, 0.13999999999999999),
#  ('radial', 28, 0.13999999999999999),
#  ('intelligence', 28, 0.13999999999999999),
#  ('singular', 28, 0.13999999999999999),
#  ('entropy', 28, 0.13999999999999999),
#  ('analyses', 28, 0.13999999999999999),
#  ('attacks', 28, 0.13999999999999999),
#  ('discontinuous', 28, 0.13999999999999999),
#  ('agent-based', 28, 0.13999999999999999),
#  ('antenna', 28, 0.13999999999999999),
#  ('words', 28, 0.13999999999999999),
#  ('optimized', 28, 0.13999999999999999),
#  ('abstract', 27, 0.135),
#  ('infrastructure', 27, 0.135),
#  ('depth', 27, 0.135),
#  ('wdm', 27, 0.135),
#  ('form', 27, 0.135),
#  ('chains', 27, 0.135),
#  ('multiscale', 27, 0.135),
#  ('resonance', 27, 0.135),
#  ('products', 27, 0.135),
#  ('surveillance', 27, 0.135),
#  ('vehicles', 27, 0.135),
#  ('threshold', 27, 0.135),
#  ('calibration', 27, 0.135),
#  ('paradigm', 27, 0.135),
#  ('alternative', 27, 0.135),
#  ('emission', 27, 0.135),
#  ('early', 27, 0.135),
#  ('using', 27, 0.135),
#  ('two-stage', 27, 0.135),
#  ('eye', 27, 0.135),
#  ('principles', 27, 0.135),
#  ('computations', 27, 0.135),
#  ('discriminant', 27, 0.135),
#  ('thin', 27, 0.135),
#  ('units', 27, 0.135),
#  ('fading', 27, 0.135),
#  ('unstructured', 27, 0.135),
#  ('neighborhood', 27, 0.135),
#  ('boltzmann', 27, 0.135),
#  ('personal', 27, 0.135),
#  ('teaching', 27, 0.135),
#  ('quantization', 27, 0.135),
#  ('music', 27, 0.135),
#  ('polynomials', 27, 0.135),
#  ('coupling', 27, 0.135),
#  ('infinite', 27, 0.135),
#  ('synthetic', 27, 0.135),
#  ('architectural', 26, 0.13),
#  ('movement', 26, 0.13),
#  ('stream', 26, 0.13),
#  ('galerkin', 26, 0.13),
#  ('variability', 26, 0.13),
#  ('energy-efficient', 26, 0.13),
#  ('fractal', 26, 0.13),
#  ('exploratory', 26, 0.13),
#  ('combination', 26, 0.13),
#  ('package', 26, 0.13),
#  ('range', 26, 0.13),
#  ('weight', 26, 0.13),
#  ('population', 26, 0.13),
#  ('work', 26, 0.13),
#  ('differences', 26, 0.13),
#  ('mean', 26, 0.13),
#  ('library', 26, 0.13),
#  ('profiles', 26, 0.13),
#  ('server', 26, 0.13),
#  ('body', 26, 0.13),
#  ('practice', 26, 0.13),
#  ('acquisition', 26, 0.13),
#  ('silicon', 26, 0.13),
#  ('plant', 26, 0.13),
#  ('vertical', 26, 0.13),
#  ('least', 26, 0.13),
#  ('shared', 26, 0.13),
#  ('mri', 26, 0.13),
#  ('strong', 26, 0.13),
#  ('regions', 26, 0.13),
#  ('ranking', 26, 0.13),
#  ('principle', 26, 0.13),
#  ('material', 26, 0.13),
#  ('middleware', 26, 0.13),
#  ('word', 25, 0.125),
#  ('shapes', 25, 0.125),
#  ('student', 25, 0.125),
#  ('usage', 25, 0.125),
#  ('orientation', 25, 0.125),
#  ('deformation', 25, 0.125),
#  ('conditional', 25, 0.125),
#  ('cooperation', 25, 0.125),
#  ('asynchronous', 25, 0.125),
#  ('importance', 25, 0.125),
#  ('customer', 25, 0.125),
#  ('objective', 25, 0.125),
#  ('pricing', 25, 0.125),
#  ('relay', 25, 0.125),
#  ('tests', 25, 0.125),
#  ('anisotropic', 25, 0.125),
#  ('simulator', 25, 0.125),
#  ('individual', 25, 0.125),
#  ('deep', 25, 0.125),
#  ('ieee', 25, 0.125),
#  ('variance', 25, 0.125),
#  ('timing', 25, 0.125),
#  ('multilevel', 25, 0.125),
#  ('reduced', 25, 0.125),
#  ('buffer', 25, 0.125),
#  ('squares', 25, 0.125),
#  ('strategic', 25, 0.125),
#  ('device', 25, 0.125),
#  ('multicore', 25, 0.125),
#  ('high-speed', 25, 0.125),
#  ('regularization', 25, 0.125),
#  ('self-organizing', 25, 0.125),
#  ('rule-based', 24, 0.12),
#  ('binding', 24, 0.12),
#  ('effectiveness', 24, 0.12),
#  ('sites', 24, 0.12),
#  ('ratio', 24, 0.12),
#  ('reaction', 24, 0.12),
#  ('gate', 24, 0.12),
#  ('low-power', 24, 0.12),
#  ('encryption', 24, 0.12),
#  ('profile', 24, 0.12),
#  ('variations', 24, 0.12),
#  ('relation', 24, 0.12),
#  ('multi-hop', 24, 0.12),
#  ('relative', 24, 0.12),
#  ('robustness', 24, 0.12),
#  ('concrete', 24, 0.12),
#  ('fiber', 24, 0.12),
#  ('immune', 24, 0.12),
#  ('coefficients', 24, 0.12),
#  ('circular', 24, 0.12),
#  ('receptor', 24, 0.12),
#  ('removal', 24, 0.12),
#  ('facial', 24, 0.12),
#  ('accessibility', 24, 0.12),
#  ('cycle', 24, 0.12),
#  ('file', 24, 0.12),
#  ('speaker', 24, 0.12),
#  ('smooth', 24, 0.12),
#  ('dependent', 24, 0.12),
#  ('higher', 24, 0.12),
#  ('irregular', 24, 0.12),
#  ('high-order', 23, 0.11499999999999999),
#  ('introduction', 23, 0.11499999999999999),
#  ('passive', 23, 0.11499999999999999),
#  ('ant', 23, 0.11499999999999999),
#  ('communities', 23, 0.11499999999999999),
#  ('instruction', 23, 0.11499999999999999),
#  ('property', 23, 0.11499999999999999),
#  ('calculations', 23, 0.11499999999999999),
#  ('equilibrium', 23, 0.11499999999999999),
#  ('precision', 23, 0.11499999999999999),
#  ('behavioral', 23, 0.11499999999999999),
#  ('asymptotic', 23, 0.11499999999999999),
#  ('enterprise', 23, 0.11499999999999999),
#  ('linguistic', 23, 0.11499999999999999),
#  ('regular', 23, 0.11499999999999999),
#  ...]

# %%
from multiprocessing import Pool

# %%
# %%time
tmp = [doc2content(d) for d in data.values()]
def worker(t):
    return t, sum(t.lower() in d.lower() for d in tmp)
doc_freq = {}
with Pool(3) as p:
    for t, f in tqdm(p.map(worker, voc.keys()), total=len(voc)):
        doc_freq[t] = f

# %%
# %%time


doc_freq = {t: sum(t.lower() in d.lower() for d in tmp) for t in list(voc.keys())}
# Out:
# CPU times: user 5min, sys: 15.9 ms, total: 5min
# Wall time: 5min

# %%
doc_freq['r']
# Out:
# 19999

# %%
from operator import itemgetter

# %%
sorted(doc_freq.items(), key=itemgetter(1), )
# Out:
# [('fmesp', 0),
#  ('(ipo', 0),
#  ('dacm', 0),
#  ('auau', 0),
#  ('(mis)', 0),
#  ('owl-eu', 0),
#  ('fec-based', 0),
#  ('deques', 0),
#  ('epons', 0),
#  ('surrogate-based', 0),
#  ('permutation-based', 0),
#  ('reuse-driven', 0),
#  ('face/hairstyle', 0),
#  ('wcdma/wlan', 0),
#  ('shock-structure', 0),
#  ('numerical/simulative', 0),
#  ('cc-rule', 0),
#  ('interns', 0),
#  ('l-machines', 0),
#  ('delaunany', 0),
#  ('misep', 0),
#  ('decison-making', 0),
#  ('ackerman', 0),
#  ('fuzzy-hybrid', 0),
#  ('radius/height', 0),
#  ('radiotherapeutic', 0),
#  ("hebb's", 0),
#  ('temporally-dependent', 0),
#  ('multiple-interests', 0),
#  ('multiple-content', 0),
#  ('mug1', 0),
#  ('vsc', 0),
#  ('squirrel', 0),
#  ('fuzzy-knowledge', 0),
#  ('cvrp', 0),
#  ('affect-aware', 0),
#  ('finfets', 0),
#  ('fdsoi', 0),
#  ('arvo-cl', 0),
#  ('(kamm', 0),
#  ('"karlsruhe', 0),
#  ('edxrf', 0),
#  ('determinates', 0),
#  ('sift-based', 0),
#  ('schelling-ising', 0),
#  ('cda+graf', 0),
#  ('glycofuranoid', 0),
#  ('menshutkin-like', 0),
#  ('o-isopropylidene-protected', 0),
#  ('prolac', 0),
#  ("pelgrom's", 0),
#  ('pcnn-based', 0),
#  ('teager-huang', 0),
#  ('b+-trees', 0),
#  ('historiographic', 0),
#  ('non-agricultural', 0),
#  ('non-controlled', 0),
#  ('structure-satisfactory', 0),
#  ('aa-trna', 0),
#  ('segbus', 0),
#  ('sorting-complexity', 0),
#  ('example-driven', 0),
#  ('(pcb)', 0),
#  ('multi-recombination', 0),
#  ('product-market', 0),
#  ('stability-optimized', 0),
#  ('(milk', 0),
#  ('lucas-kanade', 0),
#  ('cmaterdb1', 0),
#  ('bangla-english', 0),
#  ('delayering', 0),
#  ('side-edge', 0),
#  ('firegrid', 0),
#  ('hardware-embedded', 0),
#  ('midgar', 0),
#  ('gcs', 0),
#  ('fourier-analytic', 0),
#  ('aho-corasick', 0),
#  ('antheprot', 0),
#  ('cardioids-based', 0),
#  ('multi-asset', 0),
#  ('(andexor', 0),
#  ('semiconductor-related', 0),
#  ('tms320c54x', 0),
#  ('mmapdng', 0),
#  ('pebd', 0),
#  ('(prbf', 0),
#  ('ca-markov', 0),
#  ('somatodendritic', 0),
#  ('fcnc', 0),
#  ('cp-violating', 0),
#  ('susy_flavorv2', 0),
#  ('mlps', 0),
#  ('petrinets', 0),
#  ('giants', 0),
#  ('islanded', 0),
#  ('situative', 0),
#  ('p-cycle-based', 0),
#  ('hyperexcitable', 0),
#  ('selgen', 0),
#  ('pid-controlled', 0),
#  ('egc', 0),
#  ('mdd-based', 0),
#  ('kuwakado-tanaka', 0),
#  ('ap-1', 0),
#  ('pask', 0),
#  ('chi-scores', 0),
#  ('transfusional', 0),
#  ('multi-fingered', 0),
#  ('bubble-fluid', 0),
#  ('close-form', 0),
#  ('drunken', 0),
#  ('hit-mw', 0),
#  ('elastostatics', 0),
#  ('multisolution', 0),
#  ('fuzzy-approximation-based', 0),
#  ('skeleton-enhanced', 0),
#  ('ahpo', 0),
#  ('hyperspeech', 0),
#  ('security-oriented', 0),
#  ('alxga1?xas/gaas', 0),
#  ('attack-prone', 0),
#  ('pivotal-based', 0),
#  ('glue-nail', 0),
#  ('qsar/qspr', 0),
#  ('stewart-gough', 0),
#  ('navigation-based', 0),
#  ('scar-based', 0),
#  ('bixid', 0),
#  ('tv-recommendation', 0),
#  ('"exotic"', 0),
#  ('k-word', 0),
#  ('lovely', 0),
#  ('time-geographic', 0),
#  ('coupling-aware', 0),
#  ('rlc', 0),
#  ('under-approximating', 0),
#  ('deep-time', 0),
#  ('cspfossil', 0),
#  ('self-managing,', 0),
#  ('factor-analysis', 0),
#  ('processor-based', 0),
#  ('ltanium', 0),
#  ('l-max', 0),
#  ('worker-constrained', 0),
#  ('danish', 0),
#  ('fesd', 0),
#  ('randomised,', 0),
#  ('srams', 0),
#  ('tcams', 0),
#  ('vacation/close-down/setup', 0),
#  ('metamorphoses', 0),
#  ('function-defined', 0),
#  ('cmos-gate-driven', 0),
#  ('museqor', 0),
#  ('explorational', 0),
#  ('excitatoryinhibitory', 0),
#  ('cds/cdte', 0),
#  ('idd-based', 0),
#  ('hci-related', 0),
#  ('ader-weno', 0),
#  ('oil-fields', 0),
#  ('2k-variable', 0),
#  ('quasi-hamiltonian-set-connected', 0),
#  ('parplay', 0),
#  ('camd', 0),
#  ('sznajd', 0),
#  ('sociophysics', 0),
#  ('imageadmixture', 0),
#  ('brazilian', 0),
#  ('3-ghz', 0),
#  ('english-thai', 0),
#  ('argos', 0),
#  ('murphy', 0),
#  ('lorentz-boosted', 0),
#  ('pauw', 0),
#  ('scomdy', 0),
#  ('neuro-genetic', 0),
#  ('heuristicgenetic', 0),
#  ('gra-based', 0),
#  ('pc-based', 0),
#  ('anx7', 0),
#  ('mccbr', 0),
#  ('hccbra', 0),
#  ('ncm', 0),
#  ('mimo/diversity', 0),
#  ('cadre', 0),
#  ('carma', 0),
#  ('issdc', 0),
#  ('javame', 0),
#  ('student-project', 0),
#  ('image1', 0),
#  ('privatised', 0),
#  ('/openbugs', 0),
#  ('dtpa', 0),
#  ('day-plattformen', 0),
#  ('kundenloyalitt', 0),
#  ('treibt', 0),
#  ('eibas', 0),
#  ('cad-based', 0),
#  ('low-fo4', 0),
#  ('delay-optimal', 0),
#  ('luts', 0),
#  ('pansystems-based', 0),
#  ('mg-rast', 0),
#  ('nanocircuitry', 0),
#  ('ex(n;{c3,,cs', 0),
#  ('pedobarographic', 0),
#  ('nationtelescope', 0),
#  ('lbsns', 0),
#  ('canetes', 0),
#  ('pasta', 0),
#  ('rna-sequencing', 0),
#  ('ultra-deep', 0),
#  ('phast', 0),
#  ('receptor-dependent', 0),
#  ('wpans', 0),
#  ('risk-driven', 0),
#  ('dexcom', 0),
#  ('medtronic', 0),
#  ('microcircuits', 0),
#  ('euler-monte', 0),
#  ('dtistudio', 0),
#  ('clusterfile:', 0),
#  ('pseudocode', 0),
#  ('dual-vdd', 0),
#  ("nakhleh's", 0),
#  ('bounded-rational', 0),
#  ('5-adic', 0),
#  ('summation-shrinking', 0),
#  ('utpref', 0),
#  ('taichung', 0),
#  ('pxr', 0),
#  ('sfed-weighted', 0),
#  ('3d-freehand-pose', 0),
#  ("zipf's", 0),
#  ('gan/algan', 0),
#  ('mc-cdma', 0),
#  ('cray-1s', 0),
#  ("spark's", 0),
#  ('surface-recorded', 0),
#  ('nonidentifiable', 0),
#  ('garrulous', 0),
#  ('lmn-convergence', 0),
#  ('edge-centric', 0),
#  ('post-scf', 0),
#  ('z-dna', 0),
#  ('b-dna', 0),
#  ('d(gpc)', 0),
#  ('a-dna', 0),
#  ('4-phenyl-1-napthyl', 0),
#  ('acetamide', 0),
#  ('dptb16', 0),
#  ('streptomyces', 0),
#  ('computer-simulated', 0),
#  ('(ptf-oled', 0),
#  ('rehearsing', 0),
#  ('200-ma,', 0),
#  ('burks', 0),
#  ('ego-sphere', 0),
#  ('multi-echelon', 0),
#  ('older,', 0),
#  ('post-hospital', 0),
#  ('dna-binding', 0),
#  ('c)-conditions', 0),
#  ('l(2,1)-labelling', 0),
#  ('aortas', 0),
#  ('tbdyfe', 0),
#  ('c-7-coloring', 0),
#  ('sn3.8ag0.7cu', 0),
#  ('vacillate', 0),
#  ('duration-dependent', 0),
#  ('it-service', 0),
#  ('demand-assignment', 0),
#  ('impact-acoustics', 0),
#  ("chebyshev's", 0),
#  ('#csp', 0),
#  ('kappa-ranges', 0),
#  ('tales', 0),
#  ('3d-viewer', 0),
#  ('2.4-ghz', 0),
#  ('qos-provisioning', 0),
#  ('low-count', 0),
#  ('3g+', 0),
#  ('multi-operators', 0),
#  ('o)-continuous', 0),
#  ('dea-based', 0),
#  ('post-poned', 0),
#  ('variable-section', 0),
#  ('step-reduced', 0),
#  ('variable-to-fixed-plus-variable-length', 0),
#  ('theorical', 0),
#  ('dct-kernel-based', 0),
#  ('c242t', 0),
#  ('(nadph', 0),
#  ('mcrl2', 0),
#  ('zapros', 0),
#  ('webmedqual', 0),
#  ('labeledin', 0),
#  ('eeg-based', 0),
#  ('gravimetry', 0),
#  ('al/si3n4/p', 0),
#  ('psychosocial/organisational', 0),
#  ('rtt-fair', 0),
#  ('tcps', 0),
#  ('dike', 0),
#  ('ac-dc-ac', 0),
#  ('grid-interfacing', 0),
#  ('cheat-prevention', 0),
#  ('-polymers', 0),
#  ('placebo-controlled', 0),
#  ('double-blind,', 0),
#  ('sheppack', 0),
#  ('(web-dbie', 0),
#  ('misconceived', 0),
#  ('interspliced', 0),
#  ('vlasiator', 0),
#  ('bananas', 0),
#  ('stereonets', 0),
#  ('deutschland', 0),
#  ('befragung', 0),
#  ('it-fhrungskrften', 0),
#  ('efunns-based', 0),
#  ('parylene-c', 0),
#  ('triazolopyridine', 0),
#  ('mglu2', 0),
#  ('load-matching', 0),
#  ('databus', 0),
#  ('sfsu', 0),
#  ('atom-cavity', 0),
#  ('data-dependence', 0),
#  ('pews', 0),
#  ("nitzberg's", 0),
#  ('non-np-hard', 0),
#  ('preventers', 0),
#  ('ababa', 0),
#  ('addis', 0),
#  ('(k)over-tilde(t', 0),
#  ('sasi', 0),
#  ('4-ethoxycarbonylmethyl-1-(piperidin-4-ylcarbonyl)-thiosemicarbazide-a', 0),
#  ('cardio-vascular', 0),
#  ('approach1', 0),
#  ('all*', 0),
#  ('mucs', 0),
#  ('vizsec', 0),
#  ('einstein-podolsky-rosen-bohm', 0),
#  ('dydap:', 0),
#  ('biopsychology-nonlinear', 0),
#  ('matlab-toolbox', 0),
#  ('application-focused', 0),
#  ('kenya', 0),
#  ('alas-ka', 0),
#  ('khan', 0),
#  ('induscon', 0),
#  ('grey-based', 0),
#  ('as+-implanted', 0),
#  ('eo-1', 0),
#  ('hyperion', 0),
#  ('preprocessor-based', 0),
#  ('graspels', 0),
#  ('irish', 0),
#  ('q-logistic', 0),
#  ('working-set', 0),
#  ('nanotribology', 0),
#  ('noetica', 0),
#  ('reliability-oriented', 0),
#  ('senescence-associated', 0),
#  ('hp-fem', 0),
#  ('ptca', 0),
#  ('spherical-mode-based', 0),
#  ('genmin', 0),
#  ('privacy-education', 0),
#  ('bubble-type', 0),
#  ('non-simple', 0),
#  ('parry', 0),
#  ('maryland', 0),
#  ('post-doppler', 0),
#  ('cryoglobulinemia-associated', 0),
#  ('hcv-related', 0),
#  ('immunocytoma', 0),
#  ('whtol', 0),
#  ('it-investments', 0),
#  ('theme-seer', 0),
#  ('mobilermi', 0),
#  ('analysisg', 0),
#  ('feedback-directed', 0),
#  ('shift-map', 0),
#  ('1-vertex-fault-tolerant', 0),
#  ("payload's", 0),
#  ('l-mcrs', 0),
#  ('shapean', 0),
#  ('esdirk', 0),
#  ('contextually-aware', 0),
#  ('zinc-bound', 0),
#  ('sensation-based', 0),
#  ('internet-style', 0),
#  ('passim', 0),
#  ('preceding-and-crossing', 0),
#  ('cvns-based', 0),
#  ('reestablishment', 0),
#  ('pessimal', 0),
#  ('softair', 0),
#  ('fmm-yukawa', 0),
#  ('variable-output-voltage', 0),
#  ('webb', 0),
#  ('semantically-annotated', 0),
#  ('product-instance', 0),
#  ('qsprs', 0),
#  ('pcbs', 0),
#  ('noc-based', 0),
#  ('newschannel', 0),
#  ('field-study', 0),
#  ('sharex3d', 0),
#  ('sapirwhorf', 0),
#  ('prior-hash', 0),
#  ('gpu-cpu', 0),
#  ('procedure-oriented', 0),
#  ('asep/md', 0),
#  ('self-growing', 0),
#  ('giotto', 0),
#  ('psychologically-based', 0),
#  ('diaphragmchest', 0),
#  ('distributed-state', 0),
#  ('digimatge', 0),
#  ('unistrokes', 0),
#  ('3d-contact', 0),
#  ('frequency-dependence', 0),
#  ('mega-micro-computer', 0),
#  ('siguccs', 0),
#  ('mixed-enhanced', 0),
#  ('sport-scheduling', 0),
#  ('multiple-venue,', 0),
#  ('buildable', 0),
#  ('cnns', 0),
#  ('grande', 0),
#  ('non-acute', 0),
#  ('(boltzmann)', 0),
#  ('bohlperron', 0),
#  ('hpg', 0),
#  ('brain-machine', 0),
#  ('memory-provision', 0),
#  ('nigeriathe', 0),
#  ('nanotube/polymer', 0),
#  ('ac(0', 0),
#  ('mongodb-based', 0),
#  ('u-lines', 0),
#  ('oshers', 0),
#  ('acs-based', 0),
#  ('highly-available', 0),
#  ('satisriability', 0),
#  ('specificity:', 0),
#  ('pharmacology(1', 0),
#  ('cp-dgps', 0),
#  ('2005:', 0),
#  ('scene-oriented', 0),
#  ('multi-centric', 0),
#  ('cell-mimic', 0),
#  ('e+e??4f,4f', 0),
#  ('ee4f?a', 0),
#  ('s-3:', 0),
#  ('disinfection', 0),
#  ('chlorcast', 0),
#  ('flabellate', 0),
#  ('jsrs', 0),
#  ('even-ranked', 0),
#  ('tinmith', 0),
#  ('lopass', 0),
#  ('mptp-mouse', 0),
#  ('perisaccadic', 0),
#  ('al/ni', 0),
#  ('ni(al)', 0),
#  ('difference/adamsbashforth', 0),
#  ('seven-link', 0),
#  ('capella', 0),
#  ('(snmf', 0),
#  ('self-descriptions', 0),
#  ('micro-grids', 0),
#  ('software-svm-based', 0),
#  ('nano-structures', 0),
#  ('autocorrelation-based', 0),
#  ('web-accessible', 0),
#  ('cream', 0),
#  ('openad/f', 0),
#  ('fmss', 0),
#  ('artkohonen', 0),
#  ('4.31-approximation', 0),
#  ('client-server-based', 0),
#  ('cache-efficient', 0),
#  ('kelpio', 0),
#  ('daisy', 0),
#  ('two-probe', 0),
#  ('object/relational', 0),
#  ('msd-based', 0),
#  ('trapdoor-free', 0),
#  ("asiacrypt'2004", 0),
#  ('hospital-based', 0),
#  ('hydrodynamic,', 0),
#  ('keyworded', 0),
#  ('rhf/dft/cis', 0),
#  ('11,12-cyclopropyl', 0),
#  ('qfg', 0),
#  ('fortunaa', 0),
#  ('kernel-conformation', 0),
#  ('outsourcing:', 0),
#  ('perforated', 0),
#  ('jpeg2000-based', 0),
#  ('patient-aligned', 0),
#  ('re-designing', 0),
#  ('berkeley', 0),
#  ('framsticks', 0),
#  ('sundance', 0),
#  ('ontonotes', 0),
#  ('clips-owl', 0),
#  ('manoeuvres', 0),
#  ('rgfga', 0),
#  ('fuzzy-bayesian', 0),
#  ('levitation-guidance', 0),
#  ('20mw', 0),
#  ('c-support', 0),
#  ('one-stop-solution', 0),
#  ("india's", 0),
#  ('b-scan', 0),
#  ('marketanalyzer', 0),
#  ('o(n[m', 0),
#  ('trustsets', 0),
#  ('multi-port', 0),
#  ('petcam-a', 0),
#  ("zealand's", 0),
#  ('t-lymphotropic', 0),
#  ('immpa', 0),
#  ('tinkerbell', 0),
#  ('(245hz)', 0),
#  ('thermocellumandclostridium', 0),
#  ('subsystemsclostridium', 0),
#  ('xcsf', 0),
#  ('designing:', 0),
#  ("'opportunity", 0),
#  ('knocks', 0),
#  ('pmlp', 0),
#  ('photoplethysmographic', 0),
#  ('representative-triangles', 0),
#  ('importance-performance', 0),
#  ('support-vector-machine-based', 0),
#  ('self-reconstructing', 0),
#  ('sfcl', 0),
#  ('(dfi)', 0),
#  ('iqual', 0),
#  ('scenes1', 0),
#  ('desktopmajic', 0),
#  ('majic', 0),
#  ('bdd-based', 0),
#  ('torontos', 0),
#  ('rom-less', 0),
#  ('multi-processors', 0),
#  ('systems-analysis', 0),
#  ('full-information', 0),
#  ('spectrum-sliced', 0),
#  ('capprobe', 0),
#  ('agentry', 0),
#  ('markov-binary', 0),
#  ('context-adaptive', 0),
#  ('anti-gad', 0),
#  ('holotrap', 0),
#  ('whithams', 0),
#  ('legendre-pseudospectral', 0),
#  ('sift-like', 0),
#  ('hllc-type', 0),
#  ('secdec', 0),
#  ('visual-sense', 0),
#  ('volant', 0),
#  ('speech-enabled', 0),
#  ('emulab', 0),
#  ('uacap', 0),
#  ('alsio2-n-si', 0),
#  ('ai-based', 0),
#  ('doctor-patient', 0),
#  ('pre-simulated', 0),
#  ('\\(hp\\)-dg', 0),
#  ('lstrkfaltg', 0),
#  ('3d-stitching', 0),
#  ('terastitcher', 0),
#  ('kcar', 0),
#  ('emotion-by-rule', 0),
#  ('/ocl', 0),
#  ('\\(p(y<x)\\', 0),
#  ('ann-enhanced', 0),
#  ('poisson-lindley', 0),
#  ('machine-rate', 0),
#  ('(plm', 0),
#  ('saldgean', 0),
#  ('ruscheweyh', 0),
#  ('wikipedia-based', 0),
#  ('levelscheme', 0),
#  ('ineractive', 0),
#  ('flexitools', 0),
#  ('ctrigger', 0),
#  ('gridlaba', 0),
#  ('gmmubm', 0),
#  ('taskonomy', 0),
#  ('h2n-(3,3)zgnr-no2', 0),
#  ('cp3', 0),
#  ('minnesota', 0),
#  ('mvp', 0),
#  ('handvr', 0),
#  ('networked-distributed', 0),
#  ('cognitive/reactive', 0),
#  ('wintrac', 0),
#  ("office's", 0),
#  ('distedit', 0),
#  ('intra-organizational', 0),
#  ('vowlan', 0),
#  ('eikonal-based', 0),
#  ('n-detections', 0),
#  ("small-signal-modeling's", 0),
#  ('whiteman', 0),
#  ('rm2', 0),
#  ('reusability1', 0),
#  ('organizational/innovation', 0),
#  ('malaysian', 0),
#  ('information-systems', 0),
#  ('lorenztian', 0),
#  ('ssds', 0),
#  ('virtec', 0),
#  ('agrarian', 0),
#  ('turkish', 0),
#  ('fahp-maut', 0),
#  ('qos-centric', 0),
#  ('time-schwarz', 0),
#  ('opdt', 0),
#  ('keypoint-based', 0),
#  ('4-points', 0),
#  ('marker-less', 0),
#  ('column-oriented', 0),
#  ('gpu-accelerated', 0),
#  ('cogadb', 0),
#  ('cmic', 0),
#  ('xmega', 0),
#  ('fpga-friendly', 0),
#  ('tisixny', 0),
#  ('aloxny', 0),
#  ('dare', 0),
#  ('sampling-ofdm', 0),
#  ('rbffca', 0),
#  ('m-smegmatis', 0),
#  ('m-fortuitum', 0),
#  ('wcag', 0),
#  ('slimp', 0),
#  ('ireland', 0),
#  ('practical-time', 0),
#  ('human-multirobot', 0),
#  ('fourier-vlasov', 0),
#  ('bi-relational', 0),
#  ('honeybees', 0),
#  ('erfolgsfaktoren', 0),
#  ('systemkonsolidierung', 0),
#  ('geschftskritische', 0),
#  ('italian', 0),
#  ('patuxent', 0),
#  ('contention-descriptive', 0),
#  ('thump', 0),
#  ('thummer', 0),
#  ('sms-capable', 0),
#  ('(finite)', 0),
#  ('cu-doping', 0),
#  ('lstm', 0),
#  ('bereitschaftspotential', 0),
#  ('gaps-supporting', 0),
#  ('atcs', 0),
#  ('failure-carrying', 0),
#  ('convergence-free', 0),
#  ('elastic-perfectly', 0),
#  ('amph-ima97', 0),
#  ('air-conditioning', 0),
#  ('viewpoints:', 0),
#  ('oil-immersed', 0),
#  ('median-type', 0),
#  ('detail-preserving', 0),
#  ('congregations', 0),
#  ('bellare-rogaway', 0),
#  ('(vge', 0),
#  ('derivartive', 0),
#  ('nsfnet', 0),
#  ('tiara', 0),
#  ('ottoman', 0),
#  ('jurassic', 0),
#  ('mdd-compiled', 0),
#  ('solid-inclusions', 0),
#  ('equatioris', 0),
#  ('patient-recognition', 0),
#  ('bcg-plus', 0),
#  ('pickups', 0),
#  ("'manicheanism", 0),
#  ('marcia', 0),
#  ('geo-annotated', 0),
#  ('bimtag', 0),
#  ('sssc-based', 0),
#  ('english-chinese', 0),
#  ('lesk-c-based', 0),
#  ('clir', 0),
#  ('garbage-collector-safety', 0),
#  ('saml', 0),
#  ('gaba-a', 0),
#  ('operator-difference', 0),
#  ('lmi-based', 0),
#  ('artinian', 0),
#  ("hrushovski's", 0),
#  ("frankenstein's", 0),
#  ("china's", 0),
#  ('railway-induced', 0),
#  ('rc-ldpc', 0),
#  ('polargrid', 0),
#  ('orbweb-a', 0),
#  ('multi-fitness', 0),
#  ('progranmming', 0),
#  ('pirana', 0),
#  ('pcluster', 0),
#  ('mass-customization', 0),
#  ('cocoa', 0),
#  ('penicillium', 0),
#  ('clp', 0),
#  ('tchr', 0),
#  ('multicandidate', 0),
#  ('widrow', 0),
#  ('neutron_cr-39', 0),
#  ('assamese', 0),
#  ('winkler', 0),
#  ('core-memory', 0),
#  ('bpeldebugger', 0),
#  ('bpel-specific', 0),
#  ('lightwave', 0),
#  ('shared-cache', 0),
#  ('dsss-cdma', 0),
#  ('eflash', 0),
#  ('atmel', 0),
#  ('regional-scale', 0),
#  ('u(n+1)q-binomial', 0),
#  ('tmbetadisc-rbf', 0),
#  ('frictionally', 0),
#  ('musclebuilder', 0),
#  ('unitizations', 0),
#  ("hironaka's", 0),
#  ('monomial-based', 0),
#  ('sse4', 0),
#  ('cordic-based', 0),
#  ('map-reduce-enabled', 0),
#  ('mri-guided', 0),
#  ('(doc)', 0),
#  ('gpelab', 0),
#  ('madam', 0),
#  ('subject-revealing', 0),
#  ('genre-revealing', 0),
#  ('phthalocyanine-based', 0),
#  ('systems-based', 0),
#  ('behavior-aware', 0),
#  ('nano-imprinting', 0),
#  ('ssd-based', 0),
#  ('circuit-aware', 0),
#  ('h-plane', 0),
#  ('interest-tree', 0),
#  ("finland's", 0),
#  ('norm-like', 0),
#  ('iem/fem', 0),
#  ('scale-type-based', 0),
#  ('p-n-p-n', 0),
#  ('daphnia', 0),
#  ('magna', 0),
#  ('non-equispaced', 0),
#  ('telemark', 0),
#  ('varioml', 0),
#  ('jivesim', 0),
#  ('cfes', 0),
#  ('pls-1)', 0),
#  ('poisson-type', 0),
#  ('telcot', 0),
#  ('stability-based', 0),
#  ('sh-sy5y', 0),
#  ('ambainis', 0),
#  ('system/38', 0),
#  ('hypertensive,', 0),
#  ('cancelers', 0),
#  ('az61', 0),
#  ('trackerdetector', 0),
#  ('sightseeing', 0),
#  ('lut-based', 0),
#  ('obiwan', 0),
#  ('gaussian-type', 0),
#  ('mesfets', 0),
#  ('rao-blackwellized', 0),
#  ('si-passivated', 0),
#  ('cost-oriented', 0),
#  ('spatially-adaptive', 0),
#  ('low-switching', 0),
#  ('absorptions', 0),
#  ('algebraically-converging', 0),
#  ('10ghz', 0),
#  ('multimedia-based', 0),
#  ('s-implications', 0),
#  ('two-handed', 0),
#  ('icagent', 0),
#  ('gps-based', 0),
#  ('hydro-mechanically', 0),
#  ('peptide/i-ag7', 0),
#  ('space-dwelling', 0),
#  ('smca', 0),
#  ('dvb-t/h', 0),
#  ('distortionless', 0),
#  ('response-based', 0),
#  ('structure-acoustic', 0),
#  ('mt2dinvmatlab-a', 0),
#  ('plls', 0),
#  ('trilinos', 0),
#  ('oo-models', 0),
#  ('non-irup', 0),
#  ('annualized', 0),
#  ('kleene-schutzenberger', 0),
#  ('ccr5', 0),
#  ('online/offline', 0),
#  ('hybrid-pleds', 0),
#  ("weyl's", 0),
#  ('modula-3', 0),
#  ('dixon-based', 0),
#  ('zipingpu', 0),
#  ('qos-friendly', 0),
#  ('self-titration', 0),
#  ('c-1-powell-sabin', 0),
#  ('average-optimal', 0),
#  ('nt/windows', 0),
#  ('unloved', 0),
#  ('positive-negative', 0),
#  ('unsplit,', 0),
#  ('cedar', 0),
#  ('/quaternary', 0),
#  ('dictation', 0),
#  ('beast', 0),
#  ('massachusetts', 0),
#  ('max-rwa', 0),
#  ('0.5v', 0),
#  ('eegs', 0),
#  ('aveiro', 0),
#  ('micro-opto-x-ray', 0),
#  ('smts', 0),
#  ('quasilinearity', 0),
#  ('nonpolynomial', 0),
#  ('e-websites', 0),
#  ('fstr-based', 0),
#  ('ornl', 0),
#  ('compartmentalized', 0),
#  ('ecvq', 0),
#  ('sunscapes', 0),
#  ('(hem', 0),
#  ('metamorphic', 0),
#  ('magmaheatns1d', 0),
#  ("pwr's", 0),
#  ('nbgossip', 0),
#  ('r-modules', 0),
#  ('pin-based', 0),
#  ('crosstalk-cancellation', 0),
#  ('substrate-bound', 0),
#  ('procurement/inspection', 0),
#  ('rebisr', 0),
#  ('(lai)', 0),
#  ('johnston', 0),
#  ('scale-varying', 0),
#  ('-k+', 0),
#  ('nckx2', 0),
#  ('ubench', 0),
#  ('toa-based', 0),
#  ('qpsk', 0),
#  ('similarity:', 0),
#  ('caidsa', 0),
#  ('yawn', 0),
#  ('teapot', 0),
#  ('p-removal', 0),
#  ('hyperoxia-induced', 0),
#  ('z(m', 0),
#  ('telescopic', 0),
#  ('coregulation', 0),
#  ('10x-real-time', 0),
#  ('multi-fpga', 0),
#  ('dreamt', 0),
#  ('poly(ethylenedioxythiophene):poly(styrenesulfonate', 0),
#  ('sops', 0),
#  ('vaporous', 0),
#  ('dsd', 0),
#  ('x-mu', 0),
#  ('consumer-based', 0),
#  ("malware's", 0),
#  ('coupled-lines', 0),
#  ('svm-based', 0),
#  ('k-additive', 0),
#  ('k-maxitive', 0),
#  ('ghz-state', 0),
#  ('cosens', 0),
#  ('sub-layer', 0),
#  ('pagerank-based', 0),
#  ('articlerank', 0),
#  ("brooks'", 0),
#  ('brooks', 0),
#  ('frederick', 0),
#  ('collars', 0),
#  ('biodegradability', 0),
#  ("nets'", 0),
#  ('fodosu', 0),
#  ('chinas', 0),
#  ('y-rotation', 0),
#  ('fsvm-cil', 0),
#  ('clustering-oriented', 0),
#  ('musculo-mechanical', 0),
#  ('bugnet', 0),
#  ('research-focused', 0),
#  ('body-gesture', 0),
#  ('t11l1', 0),
#  ('seivis', 0),
#  ('imaging:', 0),
#  ('tfh', 0),
#  ('dpsk-ocdm', 0),
#  ('fbdds', 0),
#  ('obdds', 0),
#  ('congestion-awareness', 0),
#  ('checkerboard-free', 0),
#  ('swcnt', 0),
#  ('bl-algebras', 0),
#  ('piperoute', 0),
#  ('reedsolomon', 0),
#  ('ahp-anp', 0),
#  ('esterel', 0),
#  ('(c-ram', 0),
#  ('meta-compiler', 0),
#  ('biouser', 0),
#  ('text-rich', 0),
#  ('post-deployment', 0),
#  ('concatenative', 0),
#  ('internet-like', 0),
#  ('single-warehouse', 0),
#  ('multiretailer', 0),
#  ('informationsverarbeitung', 0),
#  ('flexiblen', 0),
#  ('dynamischen', 0),
#  ('peano', 0),
#  ('topic-labeled', 0),
#  ('lightslice', 0),
#  ('zero-sum', 0),
#  ('vsc-based', 0),
#  ('buffer-constrained', 0),
#  ('mcore', 0),
#  ('scaled-down', 0),
#  ('1-nn', 0),
#  ('qsia', 0),
#  ('renamings', 0),
#  ('web-automatic', 0),
#  ('sdiot:', 0),
#  ('zno/cu/zno', 0),
#  ('garch(1,1', 0),
#  ('pwr', 0),
#  ('pca-based', 0),
#  ('multisemilattice:', 0),
#  ('binary-to-multidigit', 0),
#  ('l1-penalised', 0),
#  ('microcantilever-based', 0),
#  ('ibgp', 0),
#  ('throughput-constrained', 0),
#  ('microrobot-based', 0),
#  ('anti-diabetic', 0),
#  ('8t-sram', 0),
#  ('model-view-adapter', 0),
#  ('rkpm', 0),
#  ('sitting-posture', 0),
#  ('diagnosispart', 0),
#  ('ni(1?x)coxmn2o4,(0?x?1', 0),
#  ('supermodular-cut', 0),
#  ('metropolis-monte', 0),
#  ('raid-10', 0),
#  ('microisps', 0),
#  ('tick-derived', 0),
#  ('(babc', 0),
#  ('physical-biological', 0),
#  ('thd-reduction', 0),
#  ('insertion-deletion-like', 0),
#  ('analysen', 0),
#  ('fachlich-konzeptionelle', 0),
#  ('mutandis', 0),
#  ('mutatis', 0),
#  ('audio-interfaces', 0),
#  ('eap-tls', 0),
#  ('usim-based', 0),
#  ('off-target', 0),
#  ('cortex-like', 0),
#  ('befe', 0),
#  ('wanets', 0),
#  ('sacta', 0),
#  ('cheapest', 0),
#  ('arthroscopy', 0),
#  ('nixmn3?xo4', 0),
#  ('kommunikationsgenres', 0),
#  ('kontextualisierung', 0),
#  ('clarke', 0),
#  ('soulsby', 0),
#  ('n-substituted', 0),
#  ('(poster', 0),
#  ('e-mili', 0),
#  ...]

# %%
import re

# %%
# %%time
tmp = [doc2content(data[d]) for d in sorted(data)]
esc = lambda t: t.replace('\\', '\\\\').replace('(', '\(').replace(')', '\)').replace('*', '\*').replace('+', '\+').replace('?', '\?').replace('[', '\[').replace(']', '\]')
esc_voc = list(map(esc, sorted(voc)))

tf = [[(len(re.findall(t, d))) for t in esc_voc] for d in tmp]
# Out:
# CPU times: user 3h 25min 44s, sys: 1.85 s, total: 3h 25min 46s
# Wall time: 3h 25min 46s
